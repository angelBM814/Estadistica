# %% [markdown]
# <a href="https://colab.research.google.com/github/angelBM814/Estadistica/blob/main/Unidad2/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Probabilidad y estadística
# ##Unidad 2
# Práctica 3.
#
# Grupo 2Y
#
# Alumno: Ángel Gabriel Barragán Martínez
#
# Docente: Dr. José Gabriel Rodríguez Rivas

# %%
import math as mt # Para utilizar factorial
from itertools import permutations
from itertools import product
import numpy as np

# %%
asistentes = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]
n = len(asistentes)
r = 4 # Representa nuestro tamaño de subconjuntos

pr = mt.factorial(n) / mt.factorial(n-r)
print("Existen ", pr, " posibles permutaciones sin repetición del total de ", n,
      " asistentes ", " en grupos de ", r, " en ", r)
print("Aquí las permutaciones")
permutacionesAsistentes = list(permutations(asistentes, r))

#Imprime las permutaciones
for permutacion in permutacionesAsistentes:
    print(permutacion)
# Out:
# Existen  5040.0  posibles permutaciones sin repetición del total de  10  asistentes   en grupos de  4  en  4
# Aquí las permutaciones
# ('a', 'b', 'c', 'd')
# ('a', 'b', 'c', 'e')
# ('a', 'b', 'c', 'f')
# ('a', 'b', 'c', 'g')
# ('a', 'b', 'c', 'h')
# ('a', 'b', 'c', 'i')
# ('a', 'b', 'c', 'j')
# ('a', 'b', 'd', 'c')
# ('a', 'b', 'd', 'e')
# ('a', 'b', 'd', 'f')
# ('a', 'b', 'd', 'g')
# ('a', 'b', 'd', 'h')
# ('a', 'b', 'd', 'i')
# ('a', 'b', 'd', 'j')
# ('a', 'b', 'e', 'c')
# ('a', 'b', 'e', 'd')
# ('a', 'b', 'e', 'f')
# ('a', 'b', 'e', 'g')
# ('a', 'b', 'e', 'h')
# ('a', 'b', 'e', 'i')
# ('a', 'b', 'e', 'j')
# ('a', 'b', 'f', 'c')
# ('a', 'b', 'f', 'd')
# ('a', 'b', 'f', 'e')
# ('a', 'b', 'f', 'g')
# ('a', 'b', 'f', 'h')
# ('a', 'b', 'f', 'i')
# ('a', 'b', 'f', 'j')
# ('a', 'b', 'g', 'c')
# ('a', 'b', 'g', 'd')
# ('a', 'b', 'g', 'e')
# ('a', 'b', 'g', 'f')
# ('a', 'b', 'g', 'h')
# ('a', 'b', 'g', 'i')
# ('a', 'b', 'g', 'j')
# ('a', 'b', 'h', 'c')
# ('a', 'b', 'h', 'd')
# ('a', 'b', 'h', 'e')
# ('a', 'b', 'h', 'f')
# ('a', 'b', 'h', 'g')
# ('a', 'b', 'h', 'i')
# ('a', 'b', 'h', 'j')
# ('a', 'b', 'i', 'c')
# ('a', 'b', 'i', 'd')
# ('a', 'b', 'i', 'e')
# ('a', 'b', 'i', 'f')
# ('a', 'b', 'i', 'g')
# ('a', 'b', 'i', 'h')
# ('a', 'b', 'i', 'j')
# ('a', 'b', 'j', 'c')
# ('a', 'b', 'j', 'd')
# ('a', 'b', 'j', 'e')
# ('a', 'b', 'j', 'f')
# ('a', 'b', 'j', 'g')
# ('a', 'b', 'j', 'h')
# ('a', 'b', 'j', 'i')
# ('a', 'c', 'b', 'd')
# ('a', 'c', 'b', 'e')
# ('a', 'c', 'b', 'f')
# ('a', 'c', 'b', 'g')
# ('a', 'c', 'b', 'h')
# ('a', 'c', 'b', 'i')
# ('a', 'c', 'b', 'j')
# ('a', 'c', 'd', 'b')
# ('a', 'c', 'd', 'e')
# ('a', 'c', 'd', 'f')
# ('a', 'c', 'd', 'g')
# ('a', 'c', 'd', 'h')
# ('a', 'c', 'd', 'i')
# ('a', 'c', 'd', 'j')
# ('a', 'c', 'e', 'b')
# ('a', 'c', 'e', 'd')
# ('a', 'c', 'e', 'f')
# ('a', 'c', 'e', 'g')
# ('a', 'c', 'e', 'h')
# ('a', 'c', 'e', 'i')
# ('a', 'c', 'e', 'j')
# ('a', 'c', 'f', 'b')
# ('a', 'c', 'f', 'd')
# ('a', 'c', 'f', 'e')
# ('a', 'c', 'f', 'g')
# ('a', 'c', 'f', 'h')
# ('a', 'c', 'f', 'i')
# ('a', 'c', 'f', 'j')
# ('a', 'c', 'g', 'b')
# ('a', 'c', 'g', 'd')
# ('a', 'c', 'g', 'e')
# ('a', 'c', 'g', 'f')
# ('a', 'c', 'g', 'h')
# ('a', 'c', 'g', 'i')
# ('a', 'c', 'g', 'j')
# ('a', 'c', 'h', 'b')
# ('a', 'c', 'h', 'd')
# ('a', 'c', 'h', 'e')
# ('a', 'c', 'h', 'f')
# ('a', 'c', 'h', 'g')
# ('a', 'c', 'h', 'i')
# ('a', 'c', 'h', 'j')
# ('a', 'c', 'i', 'b')
# ('a', 'c', 'i', 'd')
# ('a', 'c', 'i', 'e')
# ('a', 'c', 'i', 'f')
# ('a', 'c', 'i', 'g')
# ('a', 'c', 'i', 'h')
# ('a', 'c', 'i', 'j')
# ('a', 'c', 'j', 'b')
# ('a', 'c', 'j', 'd')
# ('a', 'c', 'j', 'e')
# ('a', 'c', 'j', 'f')
# ('a', 'c', 'j', 'g')
# ('a', 'c', 'j', 'h')
# ('a', 'c', 'j', 'i')
# ('a', 'd', 'b', 'c')
# ('a', 'd', 'b', 'e')
# ('a', 'd', 'b', 'f')
# ('a', 'd', 'b', 'g')
# ('a', 'd', 'b', 'h')
# ('a', 'd', 'b', 'i')
# ('a', 'd', 'b', 'j')
# ('a', 'd', 'c', 'b')
# ('a', 'd', 'c', 'e')
# ('a', 'd', 'c', 'f')
# ('a', 'd', 'c', 'g')
# ('a', 'd', 'c', 'h')
# ('a', 'd', 'c', 'i')
# ('a', 'd', 'c', 'j')
# ('a', 'd', 'e', 'b')
# ('a', 'd', 'e', 'c')
# ('a', 'd', 'e', 'f')
# ('a', 'd', 'e', 'g')
# ('a', 'd', 'e', 'h')
# ('a', 'd', 'e', 'i')
# ('a', 'd', 'e', 'j')
# ('a', 'd', 'f', 'b')
# ('a', 'd', 'f', 'c')
# ('a', 'd', 'f', 'e')
# ('a', 'd', 'f', 'g')
# ('a', 'd', 'f', 'h')
# ('a', 'd', 'f', 'i')
# ('a', 'd', 'f', 'j')
# ('a', 'd', 'g', 'b')
# ('a', 'd', 'g', 'c')
# ('a', 'd', 'g', 'e')
# ('a', 'd', 'g', 'f')
# ('a', 'd', 'g', 'h')
# ('a', 'd', 'g', 'i')
# ('a', 'd', 'g', 'j')
# ('a', 'd', 'h', 'b')
# ('a', 'd', 'h', 'c')
# ('a', 'd', 'h', 'e')
# ('a', 'd', 'h', 'f')
# ('a', 'd', 'h', 'g')
# ('a', 'd', 'h', 'i')
# ('a', 'd', 'h', 'j')
# ('a', 'd', 'i', 'b')
# ('a', 'd', 'i', 'c')
# ('a', 'd', 'i', 'e')
# ('a', 'd', 'i', 'f')
# ('a', 'd', 'i', 'g')
# ('a', 'd', 'i', 'h')
# ('a', 'd', 'i', 'j')
# ('a', 'd', 'j', 'b')
# ('a', 'd', 'j', 'c')
# ('a', 'd', 'j', 'e')
# ('a', 'd', 'j', 'f')
# ('a', 'd', 'j', 'g')
# ('a', 'd', 'j', 'h')
# ('a', 'd', 'j', 'i')
# ('a', 'e', 'b', 'c')
# ('a', 'e', 'b', 'd')
# ('a', 'e', 'b', 'f')
# ('a', 'e', 'b', 'g')
# ('a', 'e', 'b', 'h')
# ('a', 'e', 'b', 'i')
# ('a', 'e', 'b', 'j')
# ('a', 'e', 'c', 'b')
# ('a', 'e', 'c', 'd')
# ('a', 'e', 'c', 'f')
# ('a', 'e', 'c', 'g')
# ('a', 'e', 'c', 'h')
# ('a', 'e', 'c', 'i')
# ('a', 'e', 'c', 'j')
# ('a', 'e', 'd', 'b')
# ('a', 'e', 'd', 'c')
# ('a', 'e', 'd', 'f')
# ('a', 'e', 'd', 'g')
# ('a', 'e', 'd', 'h')
# ('a', 'e', 'd', 'i')
# ('a', 'e', 'd', 'j')
# ('a', 'e', 'f', 'b')
# ('a', 'e', 'f', 'c')
# ('a', 'e', 'f', 'd')
# ('a', 'e', 'f', 'g')
# ('a', 'e', 'f', 'h')
# ('a', 'e', 'f', 'i')
# ('a', 'e', 'f', 'j')
# ('a', 'e', 'g', 'b')
# ('a', 'e', 'g', 'c')
# ('a', 'e', 'g', 'd')
# ('a', 'e', 'g', 'f')
# ('a', 'e', 'g', 'h')
# ('a', 'e', 'g', 'i')
# ('a', 'e', 'g', 'j')
# ('a', 'e', 'h', 'b')
# ('a', 'e', 'h', 'c')
# ('a', 'e', 'h', 'd')
# ('a', 'e', 'h', 'f')
# ('a', 'e', 'h', 'g')
# ('a', 'e', 'h', 'i')
# ('a', 'e', 'h', 'j')
# ('a', 'e', 'i', 'b')
# ('a', 'e', 'i', 'c')
# ('a', 'e', 'i', 'd')
# ('a', 'e', 'i', 'f')
# ('a', 'e', 'i', 'g')
# ('a', 'e', 'i', 'h')
# ('a', 'e', 'i', 'j')
# ('a', 'e', 'j', 'b')
# ('a', 'e', 'j', 'c')
# ('a', 'e', 'j', 'd')
# ('a', 'e', 'j', 'f')
# ('a', 'e', 'j', 'g')
# ('a', 'e', 'j', 'h')
# ('a', 'e', 'j', 'i')
# ('a', 'f', 'b', 'c')
# ('a', 'f', 'b', 'd')
# ('a', 'f', 'b', 'e')
# ('a', 'f', 'b', 'g')
# ('a', 'f', 'b', 'h')
# ('a', 'f', 'b', 'i')
# ('a', 'f', 'b', 'j')
# ('a', 'f', 'c', 'b')
# ('a', 'f', 'c', 'd')
# ('a', 'f', 'c', 'e')
# ('a', 'f', 'c', 'g')
# ('a', 'f', 'c', 'h')
# ('a', 'f', 'c', 'i')
# ('a', 'f', 'c', 'j')
# ('a', 'f', 'd', 'b')
# ('a', 'f', 'd', 'c')
# ('a', 'f', 'd', 'e')
# ('a', 'f', 'd', 'g')
# ('a', 'f', 'd', 'h')
# ('a', 'f', 'd', 'i')
# ('a', 'f', 'd', 'j')
# ('a', 'f', 'e', 'b')
# ('a', 'f', 'e', 'c')
# ('a', 'f', 'e', 'd')
# ('a', 'f', 'e', 'g')
# ('a', 'f', 'e', 'h')
# ('a', 'f', 'e', 'i')
# ('a', 'f', 'e', 'j')
# ('a', 'f', 'g', 'b')
# ('a', 'f', 'g', 'c')
# ('a', 'f', 'g', 'd')
# ('a', 'f', 'g', 'e')
# ('a', 'f', 'g', 'h')
# ('a', 'f', 'g', 'i')
# ('a', 'f', 'g', 'j')
# ('a', 'f', 'h', 'b')
# ('a', 'f', 'h', 'c')
# ('a', 'f', 'h', 'd')
# ('a', 'f', 'h', 'e')
# ('a', 'f', 'h', 'g')
# ('a', 'f', 'h', 'i')
# ('a', 'f', 'h', 'j')
# ('a', 'f', 'i', 'b')
# ('a', 'f', 'i', 'c')
# ('a', 'f', 'i', 'd')
# ('a', 'f', 'i', 'e')
# ('a', 'f', 'i', 'g')
# ('a', 'f', 'i', 'h')
# ('a', 'f', 'i', 'j')
# ('a', 'f', 'j', 'b')
# ('a', 'f', 'j', 'c')
# ('a', 'f', 'j', 'd')
# ('a', 'f', 'j', 'e')
# ('a', 'f', 'j', 'g')
# ('a', 'f', 'j', 'h')
# ('a', 'f', 'j', 'i')
# ('a', 'g', 'b', 'c')
# ('a', 'g', 'b', 'd')
# ('a', 'g', 'b', 'e')
# ('a', 'g', 'b', 'f')
# ('a', 'g', 'b', 'h')
# ('a', 'g', 'b', 'i')
# ('a', 'g', 'b', 'j')
# ('a', 'g', 'c', 'b')
# ('a', 'g', 'c', 'd')
# ('a', 'g', 'c', 'e')
# ('a', 'g', 'c', 'f')
# ('a', 'g', 'c', 'h')
# ('a', 'g', 'c', 'i')
# ('a', 'g', 'c', 'j')
# ('a', 'g', 'd', 'b')
# ('a', 'g', 'd', 'c')
# ('a', 'g', 'd', 'e')
# ('a', 'g', 'd', 'f')
# ('a', 'g', 'd', 'h')
# ('a', 'g', 'd', 'i')
# ('a', 'g', 'd', 'j')
# ('a', 'g', 'e', 'b')
# ('a', 'g', 'e', 'c')
# ('a', 'g', 'e', 'd')
# ('a', 'g', 'e', 'f')
# ('a', 'g', 'e', 'h')
# ('a', 'g', 'e', 'i')
# ('a', 'g', 'e', 'j')
# ('a', 'g', 'f', 'b')
# ('a', 'g', 'f', 'c')
# ('a', 'g', 'f', 'd')
# ('a', 'g', 'f', 'e')
# ('a', 'g', 'f', 'h')
# ('a', 'g', 'f', 'i')
# ('a', 'g', 'f', 'j')
# ('a', 'g', 'h', 'b')
# ('a', 'g', 'h', 'c')
# ('a', 'g', 'h', 'd')
# ('a', 'g', 'h', 'e')
# ('a', 'g', 'h', 'f')
# ('a', 'g', 'h', 'i')
# ('a', 'g', 'h', 'j')
# ('a', 'g', 'i', 'b')
# ('a', 'g', 'i', 'c')
# ('a', 'g', 'i', 'd')
# ('a', 'g', 'i', 'e')
# ('a', 'g', 'i', 'f')
# ('a', 'g', 'i', 'h')
# ('a', 'g', 'i', 'j')
# ('a', 'g', 'j', 'b')
# ('a', 'g', 'j', 'c')
# ('a', 'g', 'j', 'd')
# ('a', 'g', 'j', 'e')
# ('a', 'g', 'j', 'f')
# ('a', 'g', 'j', 'h')
# ('a', 'g', 'j', 'i')
# ('a', 'h', 'b', 'c')
# ('a', 'h', 'b', 'd')
# ('a', 'h', 'b', 'e')
# ('a', 'h', 'b', 'f')
# ('a', 'h', 'b', 'g')
# ('a', 'h', 'b', 'i')
# ('a', 'h', 'b', 'j')
# ('a', 'h', 'c', 'b')
# ('a', 'h', 'c', 'd')
# ('a', 'h', 'c', 'e')
# ('a', 'h', 'c', 'f')
# ('a', 'h', 'c', 'g')
# ('a', 'h', 'c', 'i')
# ('a', 'h', 'c', 'j')
# ('a', 'h', 'd', 'b')
# ('a', 'h', 'd', 'c')
# ('a', 'h', 'd', 'e')
# ('a', 'h', 'd', 'f')
# ('a', 'h', 'd', 'g')
# ('a', 'h', 'd', 'i')
# ('a', 'h', 'd', 'j')
# ('a', 'h', 'e', 'b')
# ('a', 'h', 'e', 'c')
# ('a', 'h', 'e', 'd')
# ('a', 'h', 'e', 'f')
# ('a', 'h', 'e', 'g')
# ('a', 'h', 'e', 'i')
# ('a', 'h', 'e', 'j')
# ('a', 'h', 'f', 'b')
# ('a', 'h', 'f', 'c')
# ('a', 'h', 'f', 'd')
# ('a', 'h', 'f', 'e')
# ('a', 'h', 'f', 'g')
# ('a', 'h', 'f', 'i')
# ('a', 'h', 'f', 'j')
# ('a', 'h', 'g', 'b')
# ('a', 'h', 'g', 'c')
# ('a', 'h', 'g', 'd')
# ('a', 'h', 'g', 'e')
# ('a', 'h', 'g', 'f')
# ('a', 'h', 'g', 'i')
# ('a', 'h', 'g', 'j')
# ('a', 'h', 'i', 'b')
# ('a', 'h', 'i', 'c')
# ('a', 'h', 'i', 'd')
# ('a', 'h', 'i', 'e')
# ('a', 'h', 'i', 'f')
# ('a', 'h', 'i', 'g')
# ('a', 'h', 'i', 'j')
# ('a', 'h', 'j', 'b')
# ('a', 'h', 'j', 'c')
# ('a', 'h', 'j', 'd')
# ('a', 'h', 'j', 'e')
# ('a', 'h', 'j', 'f')
# ('a', 'h', 'j', 'g')
# ('a', 'h', 'j', 'i')
# ('a', 'i', 'b', 'c')
# ('a', 'i', 'b', 'd')
# ('a', 'i', 'b', 'e')
# ('a', 'i', 'b', 'f')
# ('a', 'i', 'b', 'g')
# ('a', 'i', 'b', 'h')
# ('a', 'i', 'b', 'j')
# ('a', 'i', 'c', 'b')
# ('a', 'i', 'c', 'd')
# ('a', 'i', 'c', 'e')
# ('a', 'i', 'c', 'f')
# ('a', 'i', 'c', 'g')
# ('a', 'i', 'c', 'h')
# ('a', 'i', 'c', 'j')
# ('a', 'i', 'd', 'b')
# ('a', 'i', 'd', 'c')
# ('a', 'i', 'd', 'e')
# ('a', 'i', 'd', 'f')
# ('a', 'i', 'd', 'g')
# ('a', 'i', 'd', 'h')
# ('a', 'i', 'd', 'j')
# ('a', 'i', 'e', 'b')
# ('a', 'i', 'e', 'c')
# ('a', 'i', 'e', 'd')
# ('a', 'i', 'e', 'f')
# ('a', 'i', 'e', 'g')
# ('a', 'i', 'e', 'h')
# ('a', 'i', 'e', 'j')
# ('a', 'i', 'f', 'b')
# ('a', 'i', 'f', 'c')
# ('a', 'i', 'f', 'd')
# ('a', 'i', 'f', 'e')
# ('a', 'i', 'f', 'g')
# ('a', 'i', 'f', 'h')
# ('a', 'i', 'f', 'j')
# ('a', 'i', 'g', 'b')
# ('a', 'i', 'g', 'c')
# ('a', 'i', 'g', 'd')
# ('a', 'i', 'g', 'e')
# ('a', 'i', 'g', 'f')
# ('a', 'i', 'g', 'h')
# ('a', 'i', 'g', 'j')
# ('a', 'i', 'h', 'b')
# ('a', 'i', 'h', 'c')
# ('a', 'i', 'h', 'd')
# ('a', 'i', 'h', 'e')
# ('a', 'i', 'h', 'f')
# ('a', 'i', 'h', 'g')
# ('a', 'i', 'h', 'j')
# ('a', 'i', 'j', 'b')
# ('a', 'i', 'j', 'c')
# ('a', 'i', 'j', 'd')
# ('a', 'i', 'j', 'e')
# ('a', 'i', 'j', 'f')
# ('a', 'i', 'j', 'g')
# ('a', 'i', 'j', 'h')
# ('a', 'j', 'b', 'c')
# ('a', 'j', 'b', 'd')
# ('a', 'j', 'b', 'e')
# ('a', 'j', 'b', 'f')
# ('a', 'j', 'b', 'g')
# ('a', 'j', 'b', 'h')
# ('a', 'j', 'b', 'i')
# ('a', 'j', 'c', 'b')
# ('a', 'j', 'c', 'd')
# ('a', 'j', 'c', 'e')
# ('a', 'j', 'c', 'f')
# ('a', 'j', 'c', 'g')
# ('a', 'j', 'c', 'h')
# ('a', 'j', 'c', 'i')
# ('a', 'j', 'd', 'b')
# ('a', 'j', 'd', 'c')
# ('a', 'j', 'd', 'e')
# ('a', 'j', 'd', 'f')
# ('a', 'j', 'd', 'g')
# ('a', 'j', 'd', 'h')
# ('a', 'j', 'd', 'i')
# ('a', 'j', 'e', 'b')
# ('a', 'j', 'e', 'c')
# ('a', 'j', 'e', 'd')
# ('a', 'j', 'e', 'f')
# ('a', 'j', 'e', 'g')
# ('a', 'j', 'e', 'h')
# ('a', 'j', 'e', 'i')
# ('a', 'j', 'f', 'b')
# ('a', 'j', 'f', 'c')
# ('a', 'j', 'f', 'd')
# ('a', 'j', 'f', 'e')
# ('a', 'j', 'f', 'g')
# ('a', 'j', 'f', 'h')
# ('a', 'j', 'f', 'i')
# ('a', 'j', 'g', 'b')
# ('a', 'j', 'g', 'c')
# ('a', 'j', 'g', 'd')
# ('a', 'j', 'g', 'e')
# ('a', 'j', 'g', 'f')
# ('a', 'j', 'g', 'h')
# ('a', 'j', 'g', 'i')
# ('a', 'j', 'h', 'b')
# ('a', 'j', 'h', 'c')
# ('a', 'j', 'h', 'd')
# ('a', 'j', 'h', 'e')
# ('a', 'j', 'h', 'f')
# ('a', 'j', 'h', 'g')
# ('a', 'j', 'h', 'i')
# ('a', 'j', 'i', 'b')
# ('a', 'j', 'i', 'c')
# ('a', 'j', 'i', 'd')
# ('a', 'j', 'i', 'e')
# ('a', 'j', 'i', 'f')
# ('a', 'j', 'i', 'g')
# ('a', 'j', 'i', 'h')
# ('b', 'a', 'c', 'd')
# ('b', 'a', 'c', 'e')
# ('b', 'a', 'c', 'f')
# ('b', 'a', 'c', 'g')
# ('b', 'a', 'c', 'h')
# ('b', 'a', 'c', 'i')
# ('b', 'a', 'c', 'j')
# ('b', 'a', 'd', 'c')
# ('b', 'a', 'd', 'e')
# ('b', 'a', 'd', 'f')
# ('b', 'a', 'd', 'g')
# ('b', 'a', 'd', 'h')
# ('b', 'a', 'd', 'i')
# ('b', 'a', 'd', 'j')
# ('b', 'a', 'e', 'c')
# ('b', 'a', 'e', 'd')
# ('b', 'a', 'e', 'f')
# ('b', 'a', 'e', 'g')
# ('b', 'a', 'e', 'h')
# ('b', 'a', 'e', 'i')
# ('b', 'a', 'e', 'j')
# ('b', 'a', 'f', 'c')
# ('b', 'a', 'f', 'd')
# ('b', 'a', 'f', 'e')
# ('b', 'a', 'f', 'g')
# ('b', 'a', 'f', 'h')
# ('b', 'a', 'f', 'i')
# ('b', 'a', 'f', 'j')
# ('b', 'a', 'g', 'c')
# ('b', 'a', 'g', 'd')
# ('b', 'a', 'g', 'e')
# ('b', 'a', 'g', 'f')
# ('b', 'a', 'g', 'h')
# ('b', 'a', 'g', 'i')
# ('b', 'a', 'g', 'j')
# ('b', 'a', 'h', 'c')
# ('b', 'a', 'h', 'd')
# ('b', 'a', 'h', 'e')
# ('b', 'a', 'h', 'f')
# ('b', 'a', 'h', 'g')
# ('b', 'a', 'h', 'i')
# ('b', 'a', 'h', 'j')
# ('b', 'a', 'i', 'c')
# ('b', 'a', 'i', 'd')
# ('b', 'a', 'i', 'e')
# ('b', 'a', 'i', 'f')
# ('b', 'a', 'i', 'g')
# ('b', 'a', 'i', 'h')
# ('b', 'a', 'i', 'j')
# ('b', 'a', 'j', 'c')
# ('b', 'a', 'j', 'd')
# ('b', 'a', 'j', 'e')
# ('b', 'a', 'j', 'f')
# ('b', 'a', 'j', 'g')
# ('b', 'a', 'j', 'h')
# ('b', 'a', 'j', 'i')
# ('b', 'c', 'a', 'd')
# ('b', 'c', 'a', 'e')
# ('b', 'c', 'a', 'f')
# ('b', 'c', 'a', 'g')
# ('b', 'c', 'a', 'h')
# ('b', 'c', 'a', 'i')
# ('b', 'c', 'a', 'j')
# ('b', 'c', 'd', 'a')
# ('b', 'c', 'd', 'e')
# ('b', 'c', 'd', 'f')
# ('b', 'c', 'd', 'g')
# ('b', 'c', 'd', 'h')
# ('b', 'c', 'd', 'i')
# ('b', 'c', 'd', 'j')
# ('b', 'c', 'e', 'a')
# ('b', 'c', 'e', 'd')
# ('b', 'c', 'e', 'f')
# ('b', 'c', 'e', 'g')
# ('b', 'c', 'e', 'h')
# ('b', 'c', 'e', 'i')
# ('b', 'c', 'e', 'j')
# ('b', 'c', 'f', 'a')
# ('b', 'c', 'f', 'd')
# ('b', 'c', 'f', 'e')
# ('b', 'c', 'f', 'g')
# ('b', 'c', 'f', 'h')
# ('b', 'c', 'f', 'i')
# ('b', 'c', 'f', 'j')
# ('b', 'c', 'g', 'a')
# ('b', 'c', 'g', 'd')
# ('b', 'c', 'g', 'e')
# ('b', 'c', 'g', 'f')
# ('b', 'c', 'g', 'h')
# ('b', 'c', 'g', 'i')
# ('b', 'c', 'g', 'j')
# ('b', 'c', 'h', 'a')
# ('b', 'c', 'h', 'd')
# ('b', 'c', 'h', 'e')
# ('b', 'c', 'h', 'f')
# ('b', 'c', 'h', 'g')
# ('b', 'c', 'h', 'i')
# ('b', 'c', 'h', 'j')
# ('b', 'c', 'i', 'a')
# ('b', 'c', 'i', 'd')
# ('b', 'c', 'i', 'e')
# ('b', 'c', 'i', 'f')
# ('b', 'c', 'i', 'g')
# ('b', 'c', 'i', 'h')
# ('b', 'c', 'i', 'j')
# ('b', 'c', 'j', 'a')
# ('b', 'c', 'j', 'd')
# ('b', 'c', 'j', 'e')
# ('b', 'c', 'j', 'f')
# ('b', 'c', 'j', 'g')
# ('b', 'c', 'j', 'h')
# ('b', 'c', 'j', 'i')
# ('b', 'd', 'a', 'c')
# ('b', 'd', 'a', 'e')
# ('b', 'd', 'a', 'f')
# ('b', 'd', 'a', 'g')
# ('b', 'd', 'a', 'h')
# ('b', 'd', 'a', 'i')
# ('b', 'd', 'a', 'j')
# ('b', 'd', 'c', 'a')
# ('b', 'd', 'c', 'e')
# ('b', 'd', 'c', 'f')
# ('b', 'd', 'c', 'g')
# ('b', 'd', 'c', 'h')
# ('b', 'd', 'c', 'i')
# ('b', 'd', 'c', 'j')
# ('b', 'd', 'e', 'a')
# ('b', 'd', 'e', 'c')
# ('b', 'd', 'e', 'f')
# ('b', 'd', 'e', 'g')
# ('b', 'd', 'e', 'h')
# ('b', 'd', 'e', 'i')
# ('b', 'd', 'e', 'j')
# ('b', 'd', 'f', 'a')
# ('b', 'd', 'f', 'c')
# ('b', 'd', 'f', 'e')
# ('b', 'd', 'f', 'g')
# ('b', 'd', 'f', 'h')
# ('b', 'd', 'f', 'i')
# ('b', 'd', 'f', 'j')
# ('b', 'd', 'g', 'a')
# ('b', 'd', 'g', 'c')
# ('b', 'd', 'g', 'e')
# ('b', 'd', 'g', 'f')
# ('b', 'd', 'g', 'h')
# ('b', 'd', 'g', 'i')
# ('b', 'd', 'g', 'j')
# ('b', 'd', 'h', 'a')
# ('b', 'd', 'h', 'c')
# ('b', 'd', 'h', 'e')
# ('b', 'd', 'h', 'f')
# ('b', 'd', 'h', 'g')
# ('b', 'd', 'h', 'i')
# ('b', 'd', 'h', 'j')
# ('b', 'd', 'i', 'a')
# ('b', 'd', 'i', 'c')
# ('b', 'd', 'i', 'e')
# ('b', 'd', 'i', 'f')
# ('b', 'd', 'i', 'g')
# ('b', 'd', 'i', 'h')
# ('b', 'd', 'i', 'j')
# ('b', 'd', 'j', 'a')
# ('b', 'd', 'j', 'c')
# ('b', 'd', 'j', 'e')
# ('b', 'd', 'j', 'f')
# ('b', 'd', 'j', 'g')
# ('b', 'd', 'j', 'h')
# ('b', 'd', 'j', 'i')
# ('b', 'e', 'a', 'c')
# ('b', 'e', 'a', 'd')
# ('b', 'e', 'a', 'f')
# ('b', 'e', 'a', 'g')
# ('b', 'e', 'a', 'h')
# ('b', 'e', 'a', 'i')
# ('b', 'e', 'a', 'j')
# ('b', 'e', 'c', 'a')
# ('b', 'e', 'c', 'd')
# ('b', 'e', 'c', 'f')
# ('b', 'e', 'c', 'g')
# ('b', 'e', 'c', 'h')
# ('b', 'e', 'c', 'i')
# ('b', 'e', 'c', 'j')
# ('b', 'e', 'd', 'a')
# ('b', 'e', 'd', 'c')
# ('b', 'e', 'd', 'f')
# ('b', 'e', 'd', 'g')
# ('b', 'e', 'd', 'h')
# ('b', 'e', 'd', 'i')
# ('b', 'e', 'd', 'j')
# ('b', 'e', 'f', 'a')
# ('b', 'e', 'f', 'c')
# ('b', 'e', 'f', 'd')
# ('b', 'e', 'f', 'g')
# ('b', 'e', 'f', 'h')
# ('b', 'e', 'f', 'i')
# ('b', 'e', 'f', 'j')
# ('b', 'e', 'g', 'a')
# ('b', 'e', 'g', 'c')
# ('b', 'e', 'g', 'd')
# ('b', 'e', 'g', 'f')
# ('b', 'e', 'g', 'h')
# ('b', 'e', 'g', 'i')
# ('b', 'e', 'g', 'j')
# ('b', 'e', 'h', 'a')
# ('b', 'e', 'h', 'c')
# ('b', 'e', 'h', 'd')
# ('b', 'e', 'h', 'f')
# ('b', 'e', 'h', 'g')
# ('b', 'e', 'h', 'i')
# ('b', 'e', 'h', 'j')
# ('b', 'e', 'i', 'a')
# ('b', 'e', 'i', 'c')
# ('b', 'e', 'i', 'd')
# ('b', 'e', 'i', 'f')
# ('b', 'e', 'i', 'g')
# ('b', 'e', 'i', 'h')
# ('b', 'e', 'i', 'j')
# ('b', 'e', 'j', 'a')
# ('b', 'e', 'j', 'c')
# ('b', 'e', 'j', 'd')
# ('b', 'e', 'j', 'f')
# ('b', 'e', 'j', 'g')
# ('b', 'e', 'j', 'h')
# ('b', 'e', 'j', 'i')
# ('b', 'f', 'a', 'c')
# ('b', 'f', 'a', 'd')
# ('b', 'f', 'a', 'e')
# ('b', 'f', 'a', 'g')
# ('b', 'f', 'a', 'h')
# ('b', 'f', 'a', 'i')
# ('b', 'f', 'a', 'j')
# ('b', 'f', 'c', 'a')
# ('b', 'f', 'c', 'd')
# ('b', 'f', 'c', 'e')
# ('b', 'f', 'c', 'g')
# ('b', 'f', 'c', 'h')
# ('b', 'f', 'c', 'i')
# ('b', 'f', 'c', 'j')
# ('b', 'f', 'd', 'a')
# ('b', 'f', 'd', 'c')
# ('b', 'f', 'd', 'e')
# ('b', 'f', 'd', 'g')
# ('b', 'f', 'd', 'h')
# ('b', 'f', 'd', 'i')
# ('b', 'f', 'd', 'j')
# ('b', 'f', 'e', 'a')
# ('b', 'f', 'e', 'c')
# ('b', 'f', 'e', 'd')
# ('b', 'f', 'e', 'g')
# ('b', 'f', 'e', 'h')
# ('b', 'f', 'e', 'i')
# ('b', 'f', 'e', 'j')
# ('b', 'f', 'g', 'a')
# ('b', 'f', 'g', 'c')
# ('b', 'f', 'g', 'd')
# ('b', 'f', 'g', 'e')
# ('b', 'f', 'g', 'h')
# ('b', 'f', 'g', 'i')
# ('b', 'f', 'g', 'j')
# ('b', 'f', 'h', 'a')
# ('b', 'f', 'h', 'c')
# ('b', 'f', 'h', 'd')
# ('b', 'f', 'h', 'e')
# ('b', 'f', 'h', 'g')
# ('b', 'f', 'h', 'i')
# ('b', 'f', 'h', 'j')
# ('b', 'f', 'i', 'a')
# ('b', 'f', 'i', 'c')
# ('b', 'f', 'i', 'd')
# ('b', 'f', 'i', 'e')
# ('b', 'f', 'i', 'g')
# ('b', 'f', 'i', 'h')
# ('b', 'f', 'i', 'j')
# ('b', 'f', 'j', 'a')
# ('b', 'f', 'j', 'c')
# ('b', 'f', 'j', 'd')
# ('b', 'f', 'j', 'e')
# ('b', 'f', 'j', 'g')
# ('b', 'f', 'j', 'h')
# ('b', 'f', 'j', 'i')
# ('b', 'g', 'a', 'c')
# ('b', 'g', 'a', 'd')
# ('b', 'g', 'a', 'e')
# ('b', 'g', 'a', 'f')
# ('b', 'g', 'a', 'h')
# ('b', 'g', 'a', 'i')
# ('b', 'g', 'a', 'j')
# ('b', 'g', 'c', 'a')
# ('b', 'g', 'c', 'd')
# ('b', 'g', 'c', 'e')
# ('b', 'g', 'c', 'f')
# ('b', 'g', 'c', 'h')
# ('b', 'g', 'c', 'i')
# ('b', 'g', 'c', 'j')
# ('b', 'g', 'd', 'a')
# ('b', 'g', 'd', 'c')
# ('b', 'g', 'd', 'e')
# ('b', 'g', 'd', 'f')
# ('b', 'g', 'd', 'h')
# ('b', 'g', 'd', 'i')
# ('b', 'g', 'd', 'j')
# ('b', 'g', 'e', 'a')
# ('b', 'g', 'e', 'c')
# ('b', 'g', 'e', 'd')
# ('b', 'g', 'e', 'f')
# ('b', 'g', 'e', 'h')
# ('b', 'g', 'e', 'i')
# ('b', 'g', 'e', 'j')
# ('b', 'g', 'f', 'a')
# ('b', 'g', 'f', 'c')
# ('b', 'g', 'f', 'd')
# ('b', 'g', 'f', 'e')
# ('b', 'g', 'f', 'h')
# ('b', 'g', 'f', 'i')
# ('b', 'g', 'f', 'j')
# ('b', 'g', 'h', 'a')
# ('b', 'g', 'h', 'c')
# ('b', 'g', 'h', 'd')
# ('b', 'g', 'h', 'e')
# ('b', 'g', 'h', 'f')
# ('b', 'g', 'h', 'i')
# ('b', 'g', 'h', 'j')
# ('b', 'g', 'i', 'a')
# ('b', 'g', 'i', 'c')
# ('b', 'g', 'i', 'd')
# ('b', 'g', 'i', 'e')
# ('b', 'g', 'i', 'f')
# ('b', 'g', 'i', 'h')
# ('b', 'g', 'i', 'j')
# ('b', 'g', 'j', 'a')
# ('b', 'g', 'j', 'c')
# ('b', 'g', 'j', 'd')
# ('b', 'g', 'j', 'e')
# ('b', 'g', 'j', 'f')
# ('b', 'g', 'j', 'h')
# ('b', 'g', 'j', 'i')
# ('b', 'h', 'a', 'c')
# ('b', 'h', 'a', 'd')
# ('b', 'h', 'a', 'e')
# ('b', 'h', 'a', 'f')
# ('b', 'h', 'a', 'g')
# ('b', 'h', 'a', 'i')
# ('b', 'h', 'a', 'j')
# ('b', 'h', 'c', 'a')
# ('b', 'h', 'c', 'd')
# ('b', 'h', 'c', 'e')
# ('b', 'h', 'c', 'f')
# ('b', 'h', 'c', 'g')
# ('b', 'h', 'c', 'i')
# ('b', 'h', 'c', 'j')
# ('b', 'h', 'd', 'a')
# ('b', 'h', 'd', 'c')
# ('b', 'h', 'd', 'e')
# ('b', 'h', 'd', 'f')
# ('b', 'h', 'd', 'g')
# ('b', 'h', 'd', 'i')
# ('b', 'h', 'd', 'j')
# ('b', 'h', 'e', 'a')
# ('b', 'h', 'e', 'c')
# ('b', 'h', 'e', 'd')
# ('b', 'h', 'e', 'f')
# ('b', 'h', 'e', 'g')
# ('b', 'h', 'e', 'i')
# ('b', 'h', 'e', 'j')
# ('b', 'h', 'f', 'a')
# ('b', 'h', 'f', 'c')
# ('b', 'h', 'f', 'd')
# ('b', 'h', 'f', 'e')
# ('b', 'h', 'f', 'g')
# ('b', 'h', 'f', 'i')
# ('b', 'h', 'f', 'j')
# ('b', 'h', 'g', 'a')
# ('b', 'h', 'g', 'c')
# ('b', 'h', 'g', 'd')
# ('b', 'h', 'g', 'e')
# ('b', 'h', 'g', 'f')
# ('b', 'h', 'g', 'i')
# ('b', 'h', 'g', 'j')
# ('b', 'h', 'i', 'a')
# ('b', 'h', 'i', 'c')
# ('b', 'h', 'i', 'd')
# ('b', 'h', 'i', 'e')
# ('b', 'h', 'i', 'f')
# ('b', 'h', 'i', 'g')
# ('b', 'h', 'i', 'j')
# ('b', 'h', 'j', 'a')
# ('b', 'h', 'j', 'c')
# ('b', 'h', 'j', 'd')
# ('b', 'h', 'j', 'e')
# ('b', 'h', 'j', 'f')
# ('b', 'h', 'j', 'g')
# ('b', 'h', 'j', 'i')
# ('b', 'i', 'a', 'c')
# ('b', 'i', 'a', 'd')
# ('b', 'i', 'a', 'e')
# ('b', 'i', 'a', 'f')
# ('b', 'i', 'a', 'g')
# ('b', 'i', 'a', 'h')
# ('b', 'i', 'a', 'j')
# ('b', 'i', 'c', 'a')
# ('b', 'i', 'c', 'd')
# ('b', 'i', 'c', 'e')
# ('b', 'i', 'c', 'f')
# ('b', 'i', 'c', 'g')
# ('b', 'i', 'c', 'h')
# ('b', 'i', 'c', 'j')
# ('b', 'i', 'd', 'a')
# ('b', 'i', 'd', 'c')
# ('b', 'i', 'd', 'e')
# ('b', 'i', 'd', 'f')
# ('b', 'i', 'd', 'g')
# ('b', 'i', 'd', 'h')
# ('b', 'i', 'd', 'j')
# ('b', 'i', 'e', 'a')
# ('b', 'i', 'e', 'c')
# ('b', 'i', 'e', 'd')
# ('b', 'i', 'e', 'f')
# ('b', 'i', 'e', 'g')
# ('b', 'i', 'e', 'h')
# ('b', 'i', 'e', 'j')
# ('b', 'i', 'f', 'a')
# ('b', 'i', 'f', 'c')
# ('b', 'i', 'f', 'd')
# ('b', 'i', 'f', 'e')
# ('b', 'i', 'f', 'g')
# ('b', 'i', 'f', 'h')
# ('b', 'i', 'f', 'j')
# ('b', 'i', 'g', 'a')
# ('b', 'i', 'g', 'c')
# ('b', 'i', 'g', 'd')
# ('b', 'i', 'g', 'e')
# ('b', 'i', 'g', 'f')
# ('b', 'i', 'g', 'h')
# ('b', 'i', 'g', 'j')
# ('b', 'i', 'h', 'a')
# ('b', 'i', 'h', 'c')
# ('b', 'i', 'h', 'd')
# ('b', 'i', 'h', 'e')
# ('b', 'i', 'h', 'f')
# ('b', 'i', 'h', 'g')
# ('b', 'i', 'h', 'j')
# ('b', 'i', 'j', 'a')
# ('b', 'i', 'j', 'c')
# ('b', 'i', 'j', 'd')
# ('b', 'i', 'j', 'e')
# ('b', 'i', 'j', 'f')
# ('b', 'i', 'j', 'g')
# ('b', 'i', 'j', 'h')
# ('b', 'j', 'a', 'c')
# ('b', 'j', 'a', 'd')
# ('b', 'j', 'a', 'e')
# ('b', 'j', 'a', 'f')
# ('b', 'j', 'a', 'g')
# ('b', 'j', 'a', 'h')
# ('b', 'j', 'a', 'i')
# ('b', 'j', 'c', 'a')
# ('b', 'j', 'c', 'd')
# ('b', 'j', 'c', 'e')
# ('b', 'j', 'c', 'f')
# ('b', 'j', 'c', 'g')
# ('b', 'j', 'c', 'h')
# ('b', 'j', 'c', 'i')
# ('b', 'j', 'd', 'a')
# ('b', 'j', 'd', 'c')
# ('b', 'j', 'd', 'e')
# ('b', 'j', 'd', 'f')
# ('b', 'j', 'd', 'g')
# ('b', 'j', 'd', 'h')
# ('b', 'j', 'd', 'i')
# ('b', 'j', 'e', 'a')
# ('b', 'j', 'e', 'c')
# ('b', 'j', 'e', 'd')
# ('b', 'j', 'e', 'f')
# ('b', 'j', 'e', 'g')
# ('b', 'j', 'e', 'h')
# ('b', 'j', 'e', 'i')
# ('b', 'j', 'f', 'a')
# ('b', 'j', 'f', 'c')
# ('b', 'j', 'f', 'd')
# ('b', 'j', 'f', 'e')
# ('b', 'j', 'f', 'g')
# ('b', 'j', 'f', 'h')
# ('b', 'j', 'f', 'i')
# ('b', 'j', 'g', 'a')
# ('b', 'j', 'g', 'c')
# ('b', 'j', 'g', 'd')
# ('b', 'j', 'g', 'e')
# ('b', 'j', 'g', 'f')
# ('b', 'j', 'g', 'h')
# ('b', 'j', 'g', 'i')
# ('b', 'j', 'h', 'a')
# ('b', 'j', 'h', 'c')
# ('b', 'j', 'h', 'd')
# ('b', 'j', 'h', 'e')
# ('b', 'j', 'h', 'f')
# ('b', 'j', 'h', 'g')
# ('b', 'j', 'h', 'i')
# ('b', 'j', 'i', 'a')
# ('b', 'j', 'i', 'c')
# ('b', 'j', 'i', 'd')
# ('b', 'j', 'i', 'e')
# ('b', 'j', 'i', 'f')
# ('b', 'j', 'i', 'g')
# ('b', 'j', 'i', 'h')
# ('c', 'a', 'b', 'd')
# ('c', 'a', 'b', 'e')
# ('c', 'a', 'b', 'f')
# ('c', 'a', 'b', 'g')
# ('c', 'a', 'b', 'h')
# ('c', 'a', 'b', 'i')
# ('c', 'a', 'b', 'j')
# ('c', 'a', 'd', 'b')
# ('c', 'a', 'd', 'e')
# ('c', 'a', 'd', 'f')
# ('c', 'a', 'd', 'g')
# ('c', 'a', 'd', 'h')
# ('c', 'a', 'd', 'i')
# ('c', 'a', 'd', 'j')
# ('c', 'a', 'e', 'b')
# ('c', 'a', 'e', 'd')
# ('c', 'a', 'e', 'f')
# ('c', 'a', 'e', 'g')
# ('c', 'a', 'e', 'h')
# ('c', 'a', 'e', 'i')
# ('c', 'a', 'e', 'j')
# ('c', 'a', 'f', 'b')
# ('c', 'a', 'f', 'd')
# ('c', 'a', 'f', 'e')
# ('c', 'a', 'f', 'g')
# ('c', 'a', 'f', 'h')
# ('c', 'a', 'f', 'i')
# ('c', 'a', 'f', 'j')
# ('c', 'a', 'g', 'b')
# ('c', 'a', 'g', 'd')
# ('c', 'a', 'g', 'e')
# ('c', 'a', 'g', 'f')
# ('c', 'a', 'g', 'h')
# ('c', 'a', 'g', 'i')
# ('c', 'a', 'g', 'j')
# ('c', 'a', 'h', 'b')
# ('c', 'a', 'h', 'd')
# ('c', 'a', 'h', 'e')
# ('c', 'a', 'h', 'f')
# ('c', 'a', 'h', 'g')
# ('c', 'a', 'h', 'i')
# ('c', 'a', 'h', 'j')
# ('c', 'a', 'i', 'b')
# ('c', 'a', 'i', 'd')
# ('c', 'a', 'i', 'e')
# ('c', 'a', 'i', 'f')
# ('c', 'a', 'i', 'g')
# ('c', 'a', 'i', 'h')
# ('c', 'a', 'i', 'j')
# ('c', 'a', 'j', 'b')
# ('c', 'a', 'j', 'd')
# ('c', 'a', 'j', 'e')
# ('c', 'a', 'j', 'f')
# ('c', 'a', 'j', 'g')
# ('c', 'a', 'j', 'h')
# ('c', 'a', 'j', 'i')
# ('c', 'b', 'a', 'd')
# ('c', 'b', 'a', 'e')
# ('c', 'b', 'a', 'f')
# ('c', 'b', 'a', 'g')
# ('c', 'b', 'a', 'h')
# ('c', 'b', 'a', 'i')
# ('c', 'b', 'a', 'j')
# ('c', 'b', 'd', 'a')
# ('c', 'b', 'd', 'e')
# ('c', 'b', 'd', 'f')
# ('c', 'b', 'd', 'g')
# ('c', 'b', 'd', 'h')
# ('c', 'b', 'd', 'i')
# ('c', 'b', 'd', 'j')
# ('c', 'b', 'e', 'a')
# ('c', 'b', 'e', 'd')
# ('c', 'b', 'e', 'f')
# ('c', 'b', 'e', 'g')
# ('c', 'b', 'e', 'h')
# ('c', 'b', 'e', 'i')
# ('c', 'b', 'e', 'j')
# ('c', 'b', 'f', 'a')
# ('c', 'b', 'f', 'd')
# ('c', 'b', 'f', 'e')
# ('c', 'b', 'f', 'g')
# ('c', 'b', 'f', 'h')
# ('c', 'b', 'f', 'i')
# ('c', 'b', 'f', 'j')
# ('c', 'b', 'g', 'a')
# ('c', 'b', 'g', 'd')
# ('c', 'b', 'g', 'e')
# ('c', 'b', 'g', 'f')
# ('c', 'b', 'g', 'h')
# ('c', 'b', 'g', 'i')
# ('c', 'b', 'g', 'j')
# ('c', 'b', 'h', 'a')
# ('c', 'b', 'h', 'd')
# ('c', 'b', 'h', 'e')
# ('c', 'b', 'h', 'f')
# ('c', 'b', 'h', 'g')
# ('c', 'b', 'h', 'i')
# ('c', 'b', 'h', 'j')
# ('c', 'b', 'i', 'a')
# ('c', 'b', 'i', 'd')
# ('c', 'b', 'i', 'e')
# ('c', 'b', 'i', 'f')
# ('c', 'b', 'i', 'g')
# ('c', 'b', 'i', 'h')
# ('c', 'b', 'i', 'j')
# ('c', 'b', 'j', 'a')
# ('c', 'b', 'j', 'd')
# ('c', 'b', 'j', 'e')
# ('c', 'b', 'j', 'f')
# ('c', 'b', 'j', 'g')
# ('c', 'b', 'j', 'h')
# ('c', 'b', 'j', 'i')
# ('c', 'd', 'a', 'b')
# ('c', 'd', 'a', 'e')
# ('c', 'd', 'a', 'f')
# ('c', 'd', 'a', 'g')
# ('c', 'd', 'a', 'h')
# ('c', 'd', 'a', 'i')
# ('c', 'd', 'a', 'j')
# ('c', 'd', 'b', 'a')
# ('c', 'd', 'b', 'e')
# ('c', 'd', 'b', 'f')
# ('c', 'd', 'b', 'g')
# ('c', 'd', 'b', 'h')
# ('c', 'd', 'b', 'i')
# ('c', 'd', 'b', 'j')
# ('c', 'd', 'e', 'a')
# ('c', 'd', 'e', 'b')
# ('c', 'd', 'e', 'f')
# ('c', 'd', 'e', 'g')
# ('c', 'd', 'e', 'h')
# ('c', 'd', 'e', 'i')
# ('c', 'd', 'e', 'j')
# ('c', 'd', 'f', 'a')
# ('c', 'd', 'f', 'b')
# ('c', 'd', 'f', 'e')
# ('c', 'd', 'f', 'g')
# ('c', 'd', 'f', 'h')
# ('c', 'd', 'f', 'i')
# ('c', 'd', 'f', 'j')
# ('c', 'd', 'g', 'a')
# ('c', 'd', 'g', 'b')
# ('c', 'd', 'g', 'e')
# ('c', 'd', 'g', 'f')
# ('c', 'd', 'g', 'h')
# ('c', 'd', 'g', 'i')
# ('c', 'd', 'g', 'j')
# ('c', 'd', 'h', 'a')
# ('c', 'd', 'h', 'b')
# ('c', 'd', 'h', 'e')
# ('c', 'd', 'h', 'f')
# ('c', 'd', 'h', 'g')
# ('c', 'd', 'h', 'i')
# ('c', 'd', 'h', 'j')
# ('c', 'd', 'i', 'a')
# ('c', 'd', 'i', 'b')
# ('c', 'd', 'i', 'e')
# ('c', 'd', 'i', 'f')
# ('c', 'd', 'i', 'g')
# ('c', 'd', 'i', 'h')
# ('c', 'd', 'i', 'j')
# ('c', 'd', 'j', 'a')
# ('c', 'd', 'j', 'b')
# ('c', 'd', 'j', 'e')
# ('c', 'd', 'j', 'f')
# ('c', 'd', 'j', 'g')
# ('c', 'd', 'j', 'h')
# ('c', 'd', 'j', 'i')
# ('c', 'e', 'a', 'b')
# ('c', 'e', 'a', 'd')
# ('c', 'e', 'a', 'f')
# ('c', 'e', 'a', 'g')
# ('c', 'e', 'a', 'h')
# ('c', 'e', 'a', 'i')
# ('c', 'e', 'a', 'j')
# ('c', 'e', 'b', 'a')
# ('c', 'e', 'b', 'd')
# ('c', 'e', 'b', 'f')
# ('c', 'e', 'b', 'g')
# ('c', 'e', 'b', 'h')
# ('c', 'e', 'b', 'i')
# ('c', 'e', 'b', 'j')
# ('c', 'e', 'd', 'a')
# ('c', 'e', 'd', 'b')
# ('c', 'e', 'd', 'f')
# ('c', 'e', 'd', 'g')
# ('c', 'e', 'd', 'h')
# ('c', 'e', 'd', 'i')
# ('c', 'e', 'd', 'j')
# ('c', 'e', 'f', 'a')
# ('c', 'e', 'f', 'b')
# ('c', 'e', 'f', 'd')
# ('c', 'e', 'f', 'g')
# ('c', 'e', 'f', 'h')
# ('c', 'e', 'f', 'i')
# ('c', 'e', 'f', 'j')
# ('c', 'e', 'g', 'a')
# ('c', 'e', 'g', 'b')
# ('c', 'e', 'g', 'd')
# ('c', 'e', 'g', 'f')
# ('c', 'e', 'g', 'h')
# ('c', 'e', 'g', 'i')
# ('c', 'e', 'g', 'j')
# ('c', 'e', 'h', 'a')
# ('c', 'e', 'h', 'b')
# ('c', 'e', 'h', 'd')
# ('c', 'e', 'h', 'f')
# ('c', 'e', 'h', 'g')
# ('c', 'e', 'h', 'i')
# ('c', 'e', 'h', 'j')
# ('c', 'e', 'i', 'a')
# ('c', 'e', 'i', 'b')
# ('c', 'e', 'i', 'd')
# ('c', 'e', 'i', 'f')
# ('c', 'e', 'i', 'g')
# ('c', 'e', 'i', 'h')
# ('c', 'e', 'i', 'j')
# ('c', 'e', 'j', 'a')
# ('c', 'e', 'j', 'b')
# ('c', 'e', 'j', 'd')
# ('c', 'e', 'j', 'f')
# ('c', 'e', 'j', 'g')
# ('c', 'e', 'j', 'h')
# ('c', 'e', 'j', 'i')
# ('c', 'f', 'a', 'b')
# ('c', 'f', 'a', 'd')
# ('c', 'f', 'a', 'e')
# ('c', 'f', 'a', 'g')
# ('c', 'f', 'a', 'h')
# ('c', 'f', 'a', 'i')
# ('c', 'f', 'a', 'j')
# ('c', 'f', 'b', 'a')
# ('c', 'f', 'b', 'd')
# ('c', 'f', 'b', 'e')
# ('c', 'f', 'b', 'g')
# ('c', 'f', 'b', 'h')
# ('c', 'f', 'b', 'i')
# ('c', 'f', 'b', 'j')
# ('c', 'f', 'd', 'a')
# ('c', 'f', 'd', 'b')
# ('c', 'f', 'd', 'e')
# ('c', 'f', 'd', 'g')
# ('c', 'f', 'd', 'h')
# ('c', 'f', 'd', 'i')
# ('c', 'f', 'd', 'j')
# ('c', 'f', 'e', 'a')
# ('c', 'f', 'e', 'b')
# ('c', 'f', 'e', 'd')
# ('c', 'f', 'e', 'g')
# ('c', 'f', 'e', 'h')
# ('c', 'f', 'e', 'i')
# ('c', 'f', 'e', 'j')
# ('c', 'f', 'g', 'a')
# ('c', 'f', 'g', 'b')
# ('c', 'f', 'g', 'd')
# ('c', 'f', 'g', 'e')
# ('c', 'f', 'g', 'h')
# ('c', 'f', 'g', 'i')
# ('c', 'f', 'g', 'j')
# ('c', 'f', 'h', 'a')
# ('c', 'f', 'h', 'b')
# ('c', 'f', 'h', 'd')
# ('c', 'f', 'h', 'e')
# ('c', 'f', 'h', 'g')
# ('c', 'f', 'h', 'i')
# ('c', 'f', 'h', 'j')
# ('c', 'f', 'i', 'a')
# ('c', 'f', 'i', 'b')
# ('c', 'f', 'i', 'd')
# ('c', 'f', 'i', 'e')
# ('c', 'f', 'i', 'g')
# ('c', 'f', 'i', 'h')
# ('c', 'f', 'i', 'j')
# ('c', 'f', 'j', 'a')
# ('c', 'f', 'j', 'b')
# ('c', 'f', 'j', 'd')
# ('c', 'f', 'j', 'e')
# ('c', 'f', 'j', 'g')
# ('c', 'f', 'j', 'h')
# ('c', 'f', 'j', 'i')
# ('c', 'g', 'a', 'b')
# ('c', 'g', 'a', 'd')
# ('c', 'g', 'a', 'e')
# ('c', 'g', 'a', 'f')
# ('c', 'g', 'a', 'h')
# ('c', 'g', 'a', 'i')
# ('c', 'g', 'a', 'j')
# ('c', 'g', 'b', 'a')
# ('c', 'g', 'b', 'd')
# ('c', 'g', 'b', 'e')
# ('c', 'g', 'b', 'f')
# ('c', 'g', 'b', 'h')
# ('c', 'g', 'b', 'i')
# ('c', 'g', 'b', 'j')
# ('c', 'g', 'd', 'a')
# ('c', 'g', 'd', 'b')
# ('c', 'g', 'd', 'e')
# ('c', 'g', 'd', 'f')
# ('c', 'g', 'd', 'h')
# ('c', 'g', 'd', 'i')
# ('c', 'g', 'd', 'j')
# ('c', 'g', 'e', 'a')
# ('c', 'g', 'e', 'b')
# ('c', 'g', 'e', 'd')
# ('c', 'g', 'e', 'f')
# ('c', 'g', 'e', 'h')
# ('c', 'g', 'e', 'i')
# ('c', 'g', 'e', 'j')
# ('c', 'g', 'f', 'a')
# ('c', 'g', 'f', 'b')
# ('c', 'g', 'f', 'd')
# ('c', 'g', 'f', 'e')
# ('c', 'g', 'f', 'h')
# ('c', 'g', 'f', 'i')
# ('c', 'g', 'f', 'j')
# ('c', 'g', 'h', 'a')
# ('c', 'g', 'h', 'b')
# ('c', 'g', 'h', 'd')
# ('c', 'g', 'h', 'e')
# ('c', 'g', 'h', 'f')
# ('c', 'g', 'h', 'i')
# ('c', 'g', 'h', 'j')
# ('c', 'g', 'i', 'a')
# ('c', 'g', 'i', 'b')
# ('c', 'g', 'i', 'd')
# ('c', 'g', 'i', 'e')
# ('c', 'g', 'i', 'f')
# ('c', 'g', 'i', 'h')
# ('c', 'g', 'i', 'j')
# ('c', 'g', 'j', 'a')
# ('c', 'g', 'j', 'b')
# ('c', 'g', 'j', 'd')
# ('c', 'g', 'j', 'e')
# ('c', 'g', 'j', 'f')
# ('c', 'g', 'j', 'h')
# ('c', 'g', 'j', 'i')
# ('c', 'h', 'a', 'b')
# ('c', 'h', 'a', 'd')
# ('c', 'h', 'a', 'e')
# ('c', 'h', 'a', 'f')
# ('c', 'h', 'a', 'g')
# ('c', 'h', 'a', 'i')
# ('c', 'h', 'a', 'j')
# ('c', 'h', 'b', 'a')
# ('c', 'h', 'b', 'd')
# ('c', 'h', 'b', 'e')
# ('c', 'h', 'b', 'f')
# ('c', 'h', 'b', 'g')
# ('c', 'h', 'b', 'i')
# ('c', 'h', 'b', 'j')
# ('c', 'h', 'd', 'a')
# ('c', 'h', 'd', 'b')
# ('c', 'h', 'd', 'e')
# ('c', 'h', 'd', 'f')
# ('c', 'h', 'd', 'g')
# ('c', 'h', 'd', 'i')
# ('c', 'h', 'd', 'j')
# ('c', 'h', 'e', 'a')
# ('c', 'h', 'e', 'b')
# ('c', 'h', 'e', 'd')
# ('c', 'h', 'e', 'f')
# ('c', 'h', 'e', 'g')
# ('c', 'h', 'e', 'i')
# ('c', 'h', 'e', 'j')
# ('c', 'h', 'f', 'a')
# ('c', 'h', 'f', 'b')
# ('c', 'h', 'f', 'd')
# ('c', 'h', 'f', 'e')
# ('c', 'h', 'f', 'g')
# ('c', 'h', 'f', 'i')
# ('c', 'h', 'f', 'j')
# ('c', 'h', 'g', 'a')
# ('c', 'h', 'g', 'b')
# ('c', 'h', 'g', 'd')
# ('c', 'h', 'g', 'e')
# ('c', 'h', 'g', 'f')
# ('c', 'h', 'g', 'i')
# ('c', 'h', 'g', 'j')
# ('c', 'h', 'i', 'a')
# ('c', 'h', 'i', 'b')
# ('c', 'h', 'i', 'd')
# ('c', 'h', 'i', 'e')
# ('c', 'h', 'i', 'f')
# ('c', 'h', 'i', 'g')
# ('c', 'h', 'i', 'j')
# ('c', 'h', 'j', 'a')
# ('c', 'h', 'j', 'b')
# ('c', 'h', 'j', 'd')
# ('c', 'h', 'j', 'e')
# ('c', 'h', 'j', 'f')
# ('c', 'h', 'j', 'g')
# ('c', 'h', 'j', 'i')
# ('c', 'i', 'a', 'b')
# ('c', 'i', 'a', 'd')
# ('c', 'i', 'a', 'e')
# ('c', 'i', 'a', 'f')
# ('c', 'i', 'a', 'g')
# ('c', 'i', 'a', 'h')
# ('c', 'i', 'a', 'j')
# ('c', 'i', 'b', 'a')
# ('c', 'i', 'b', 'd')
# ('c', 'i', 'b', 'e')
# ('c', 'i', 'b', 'f')
# ('c', 'i', 'b', 'g')
# ('c', 'i', 'b', 'h')
# ('c', 'i', 'b', 'j')
# ('c', 'i', 'd', 'a')
# ('c', 'i', 'd', 'b')
# ('c', 'i', 'd', 'e')
# ('c', 'i', 'd', 'f')
# ('c', 'i', 'd', 'g')
# ('c', 'i', 'd', 'h')
# ('c', 'i', 'd', 'j')
# ('c', 'i', 'e', 'a')
# ('c', 'i', 'e', 'b')
# ('c', 'i', 'e', 'd')
# ('c', 'i', 'e', 'f')
# ('c', 'i', 'e', 'g')
# ('c', 'i', 'e', 'h')
# ('c', 'i', 'e', 'j')
# ('c', 'i', 'f', 'a')
# ('c', 'i', 'f', 'b')
# ('c', 'i', 'f', 'd')
# ('c', 'i', 'f', 'e')
# ('c', 'i', 'f', 'g')
# ('c', 'i', 'f', 'h')
# ('c', 'i', 'f', 'j')
# ('c', 'i', 'g', 'a')
# ('c', 'i', 'g', 'b')
# ('c', 'i', 'g', 'd')
# ('c', 'i', 'g', 'e')
# ('c', 'i', 'g', 'f')
# ('c', 'i', 'g', 'h')
# ('c', 'i', 'g', 'j')
# ('c', 'i', 'h', 'a')
# ('c', 'i', 'h', 'b')
# ('c', 'i', 'h', 'd')
# ('c', 'i', 'h', 'e')
# ('c', 'i', 'h', 'f')
# ('c', 'i', 'h', 'g')
# ('c', 'i', 'h', 'j')
# ('c', 'i', 'j', 'a')
# ('c', 'i', 'j', 'b')
# ('c', 'i', 'j', 'd')
# ('c', 'i', 'j', 'e')
# ('c', 'i', 'j', 'f')
# ('c', 'i', 'j', 'g')
# ('c', 'i', 'j', 'h')
# ('c', 'j', 'a', 'b')
# ('c', 'j', 'a', 'd')
# ('c', 'j', 'a', 'e')
# ('c', 'j', 'a', 'f')
# ('c', 'j', 'a', 'g')
# ('c', 'j', 'a', 'h')
# ('c', 'j', 'a', 'i')
# ('c', 'j', 'b', 'a')
# ('c', 'j', 'b', 'd')
# ('c', 'j', 'b', 'e')
# ('c', 'j', 'b', 'f')
# ('c', 'j', 'b', 'g')
# ('c', 'j', 'b', 'h')
# ('c', 'j', 'b', 'i')
# ('c', 'j', 'd', 'a')
# ('c', 'j', 'd', 'b')
# ('c', 'j', 'd', 'e')
# ('c', 'j', 'd', 'f')
# ('c', 'j', 'd', 'g')
# ('c', 'j', 'd', 'h')
# ('c', 'j', 'd', 'i')
# ('c', 'j', 'e', 'a')
# ('c', 'j', 'e', 'b')
# ('c', 'j', 'e', 'd')
# ('c', 'j', 'e', 'f')
# ('c', 'j', 'e', 'g')
# ('c', 'j', 'e', 'h')
# ('c', 'j', 'e', 'i')
# ('c', 'j', 'f', 'a')
# ('c', 'j', 'f', 'b')
# ('c', 'j', 'f', 'd')
# ('c', 'j', 'f', 'e')
# ('c', 'j', 'f', 'g')
# ('c', 'j', 'f', 'h')
# ('c', 'j', 'f', 'i')
# ('c', 'j', 'g', 'a')
# ('c', 'j', 'g', 'b')
# ('c', 'j', 'g', 'd')
# ('c', 'j', 'g', 'e')
# ('c', 'j', 'g', 'f')
# ('c', 'j', 'g', 'h')
# ('c', 'j', 'g', 'i')
# ('c', 'j', 'h', 'a')
# ('c', 'j', 'h', 'b')
# ('c', 'j', 'h', 'd')
# ('c', 'j', 'h', 'e')
# ('c', 'j', 'h', 'f')
# ('c', 'j', 'h', 'g')
# ('c', 'j', 'h', 'i')
# ('c', 'j', 'i', 'a')
# ('c', 'j', 'i', 'b')
# ('c', 'j', 'i', 'd')
# ('c', 'j', 'i', 'e')
# ('c', 'j', 'i', 'f')
# ('c', 'j', 'i', 'g')
# ('c', 'j', 'i', 'h')
# ('d', 'a', 'b', 'c')
# ('d', 'a', 'b', 'e')
# ('d', 'a', 'b', 'f')
# ('d', 'a', 'b', 'g')
# ('d', 'a', 'b', 'h')
# ('d', 'a', 'b', 'i')
# ('d', 'a', 'b', 'j')
# ('d', 'a', 'c', 'b')
# ('d', 'a', 'c', 'e')
# ('d', 'a', 'c', 'f')
# ('d', 'a', 'c', 'g')
# ('d', 'a', 'c', 'h')
# ('d', 'a', 'c', 'i')
# ('d', 'a', 'c', 'j')
# ('d', 'a', 'e', 'b')
# ('d', 'a', 'e', 'c')
# ('d', 'a', 'e', 'f')
# ('d', 'a', 'e', 'g')
# ('d', 'a', 'e', 'h')
# ('d', 'a', 'e', 'i')
# ('d', 'a', 'e', 'j')
# ('d', 'a', 'f', 'b')
# ('d', 'a', 'f', 'c')
# ('d', 'a', 'f', 'e')
# ('d', 'a', 'f', 'g')
# ('d', 'a', 'f', 'h')
# ('d', 'a', 'f', 'i')
# ('d', 'a', 'f', 'j')
# ('d', 'a', 'g', 'b')
# ('d', 'a', 'g', 'c')
# ('d', 'a', 'g', 'e')
# ('d', 'a', 'g', 'f')
# ('d', 'a', 'g', 'h')
# ('d', 'a', 'g', 'i')
# ('d', 'a', 'g', 'j')
# ('d', 'a', 'h', 'b')
# ('d', 'a', 'h', 'c')
# ('d', 'a', 'h', 'e')
# ('d', 'a', 'h', 'f')
# ('d', 'a', 'h', 'g')
# ('d', 'a', 'h', 'i')
# ('d', 'a', 'h', 'j')
# ('d', 'a', 'i', 'b')
# ('d', 'a', 'i', 'c')
# ('d', 'a', 'i', 'e')
# ('d', 'a', 'i', 'f')
# ('d', 'a', 'i', 'g')
# ('d', 'a', 'i', 'h')
# ('d', 'a', 'i', 'j')
# ('d', 'a', 'j', 'b')
# ('d', 'a', 'j', 'c')
# ('d', 'a', 'j', 'e')
# ('d', 'a', 'j', 'f')
# ('d', 'a', 'j', 'g')
# ('d', 'a', 'j', 'h')
# ('d', 'a', 'j', 'i')
# ('d', 'b', 'a', 'c')
# ('d', 'b', 'a', 'e')
# ('d', 'b', 'a', 'f')
# ('d', 'b', 'a', 'g')
# ('d', 'b', 'a', 'h')
# ('d', 'b', 'a', 'i')
# ('d', 'b', 'a', 'j')
# ('d', 'b', 'c', 'a')
# ('d', 'b', 'c', 'e')
# ('d', 'b', 'c', 'f')
# ('d', 'b', 'c', 'g')
# ('d', 'b', 'c', 'h')
# ('d', 'b', 'c', 'i')
# ('d', 'b', 'c', 'j')
# ('d', 'b', 'e', 'a')
# ('d', 'b', 'e', 'c')
# ('d', 'b', 'e', 'f')
# ('d', 'b', 'e', 'g')
# ('d', 'b', 'e', 'h')
# ('d', 'b', 'e', 'i')
# ('d', 'b', 'e', 'j')
# ('d', 'b', 'f', 'a')
# ('d', 'b', 'f', 'c')
# ('d', 'b', 'f', 'e')
# ('d', 'b', 'f', 'g')
# ('d', 'b', 'f', 'h')
# ('d', 'b', 'f', 'i')
# ('d', 'b', 'f', 'j')
# ('d', 'b', 'g', 'a')
# ('d', 'b', 'g', 'c')
# ('d', 'b', 'g', 'e')
# ('d', 'b', 'g', 'f')
# ('d', 'b', 'g', 'h')
# ('d', 'b', 'g', 'i')
# ('d', 'b', 'g', 'j')
# ('d', 'b', 'h', 'a')
# ('d', 'b', 'h', 'c')
# ('d', 'b', 'h', 'e')
# ('d', 'b', 'h', 'f')
# ('d', 'b', 'h', 'g')
# ('d', 'b', 'h', 'i')
# ('d', 'b', 'h', 'j')
# ('d', 'b', 'i', 'a')
# ('d', 'b', 'i', 'c')
# ('d', 'b', 'i', 'e')
# ('d', 'b', 'i', 'f')
# ('d', 'b', 'i', 'g')
# ('d', 'b', 'i', 'h')
# ('d', 'b', 'i', 'j')
# ('d', 'b', 'j', 'a')
# ('d', 'b', 'j', 'c')
# ('d', 'b', 'j', 'e')
# ('d', 'b', 'j', 'f')
# ('d', 'b', 'j', 'g')
# ('d', 'b', 'j', 'h')
# ('d', 'b', 'j', 'i')
# ('d', 'c', 'a', 'b')
# ('d', 'c', 'a', 'e')
# ('d', 'c', 'a', 'f')
# ('d', 'c', 'a', 'g')
# ('d', 'c', 'a', 'h')
# ('d', 'c', 'a', 'i')
# ('d', 'c', 'a', 'j')
# ('d', 'c', 'b', 'a')
# ('d', 'c', 'b', 'e')
# ('d', 'c', 'b', 'f')
# ('d', 'c', 'b', 'g')
# ('d', 'c', 'b', 'h')
# ('d', 'c', 'b', 'i')
# ('d', 'c', 'b', 'j')
# ('d', 'c', 'e', 'a')
# ('d', 'c', 'e', 'b')
# ('d', 'c', 'e', 'f')
# ('d', 'c', 'e', 'g')
# ('d', 'c', 'e', 'h')
# ('d', 'c', 'e', 'i')
# ('d', 'c', 'e', 'j')
# ('d', 'c', 'f', 'a')
# ('d', 'c', 'f', 'b')
# ('d', 'c', 'f', 'e')
# ('d', 'c', 'f', 'g')
# ('d', 'c', 'f', 'h')
# ('d', 'c', 'f', 'i')
# ('d', 'c', 'f', 'j')
# ('d', 'c', 'g', 'a')
# ('d', 'c', 'g', 'b')
# ('d', 'c', 'g', 'e')
# ('d', 'c', 'g', 'f')
# ('d', 'c', 'g', 'h')
# ('d', 'c', 'g', 'i')
# ('d', 'c', 'g', 'j')
# ('d', 'c', 'h', 'a')
# ('d', 'c', 'h', 'b')
# ('d', 'c', 'h', 'e')
# ('d', 'c', 'h', 'f')
# ('d', 'c', 'h', 'g')
# ('d', 'c', 'h', 'i')
# ('d', 'c', 'h', 'j')
# ('d', 'c', 'i', 'a')
# ('d', 'c', 'i', 'b')
# ('d', 'c', 'i', 'e')
# ('d', 'c', 'i', 'f')
# ('d', 'c', 'i', 'g')
# ('d', 'c', 'i', 'h')
# ('d', 'c', 'i', 'j')
# ('d', 'c', 'j', 'a')
# ('d', 'c', 'j', 'b')
# ('d', 'c', 'j', 'e')
# ('d', 'c', 'j', 'f')
# ('d', 'c', 'j', 'g')
# ('d', 'c', 'j', 'h')
# ('d', 'c', 'j', 'i')
# ('d', 'e', 'a', 'b')
# ('d', 'e', 'a', 'c')
# ('d', 'e', 'a', 'f')
# ('d', 'e', 'a', 'g')
# ('d', 'e', 'a', 'h')
# ('d', 'e', 'a', 'i')
# ('d', 'e', 'a', 'j')
# ('d', 'e', 'b', 'a')
# ('d', 'e', 'b', 'c')
# ('d', 'e', 'b', 'f')
# ('d', 'e', 'b', 'g')
# ('d', 'e', 'b', 'h')
# ('d', 'e', 'b', 'i')
# ('d', 'e', 'b', 'j')
# ('d', 'e', 'c', 'a')
# ('d', 'e', 'c', 'b')
# ('d', 'e', 'c', 'f')
# ('d', 'e', 'c', 'g')
# ('d', 'e', 'c', 'h')
# ('d', 'e', 'c', 'i')
# ('d', 'e', 'c', 'j')
# ('d', 'e', 'f', 'a')
# ('d', 'e', 'f', 'b')
# ('d', 'e', 'f', 'c')
# ('d', 'e', 'f', 'g')
# ('d', 'e', 'f', 'h')
# ('d', 'e', 'f', 'i')
# ('d', 'e', 'f', 'j')
# ('d', 'e', 'g', 'a')
# ('d', 'e', 'g', 'b')
# ('d', 'e', 'g', 'c')
# ('d', 'e', 'g', 'f')
# ('d', 'e', 'g', 'h')
# ('d', 'e', 'g', 'i')
# ('d', 'e', 'g', 'j')
# ('d', 'e', 'h', 'a')
# ('d', 'e', 'h', 'b')
# ('d', 'e', 'h', 'c')
# ('d', 'e', 'h', 'f')
# ('d', 'e', 'h', 'g')
# ('d', 'e', 'h', 'i')
# ('d', 'e', 'h', 'j')
# ('d', 'e', 'i', 'a')
# ('d', 'e', 'i', 'b')
# ('d', 'e', 'i', 'c')
# ('d', 'e', 'i', 'f')
# ('d', 'e', 'i', 'g')
# ('d', 'e', 'i', 'h')
# ('d', 'e', 'i', 'j')
# ('d', 'e', 'j', 'a')
# ('d', 'e', 'j', 'b')
# ('d', 'e', 'j', 'c')
# ('d', 'e', 'j', 'f')
# ('d', 'e', 'j', 'g')
# ('d', 'e', 'j', 'h')
# ('d', 'e', 'j', 'i')
# ('d', 'f', 'a', 'b')
# ('d', 'f', 'a', 'c')
# ('d', 'f', 'a', 'e')
# ('d', 'f', 'a', 'g')
# ('d', 'f', 'a', 'h')
# ('d', 'f', 'a', 'i')
# ('d', 'f', 'a', 'j')
# ('d', 'f', 'b', 'a')
# ('d', 'f', 'b', 'c')
# ('d', 'f', 'b', 'e')
# ('d', 'f', 'b', 'g')
# ('d', 'f', 'b', 'h')
# ('d', 'f', 'b', 'i')
# ('d', 'f', 'b', 'j')
# ('d', 'f', 'c', 'a')
# ('d', 'f', 'c', 'b')
# ('d', 'f', 'c', 'e')
# ('d', 'f', 'c', 'g')
# ('d', 'f', 'c', 'h')
# ('d', 'f', 'c', 'i')
# ('d', 'f', 'c', 'j')
# ('d', 'f', 'e', 'a')
# ('d', 'f', 'e', 'b')
# ('d', 'f', 'e', 'c')
# ('d', 'f', 'e', 'g')
# ('d', 'f', 'e', 'h')
# ('d', 'f', 'e', 'i')
# ('d', 'f', 'e', 'j')
# ('d', 'f', 'g', 'a')
# ('d', 'f', 'g', 'b')
# ('d', 'f', 'g', 'c')
# ('d', 'f', 'g', 'e')
# ('d', 'f', 'g', 'h')
# ('d', 'f', 'g', 'i')
# ('d', 'f', 'g', 'j')
# ('d', 'f', 'h', 'a')
# ('d', 'f', 'h', 'b')
# ('d', 'f', 'h', 'c')
# ('d', 'f', 'h', 'e')
# ('d', 'f', 'h', 'g')
# ('d', 'f', 'h', 'i')
# ('d', 'f', 'h', 'j')
# ('d', 'f', 'i', 'a')
# ('d', 'f', 'i', 'b')
# ('d', 'f', 'i', 'c')
# ('d', 'f', 'i', 'e')
# ('d', 'f', 'i', 'g')
# ('d', 'f', 'i', 'h')
# ('d', 'f', 'i', 'j')
# ('d', 'f', 'j', 'a')
# ('d', 'f', 'j', 'b')
# ('d', 'f', 'j', 'c')
# ('d', 'f', 'j', 'e')
# ('d', 'f', 'j', 'g')
# ('d', 'f', 'j', 'h')
# ('d', 'f', 'j', 'i')
# ('d', 'g', 'a', 'b')
# ('d', 'g', 'a', 'c')
# ('d', 'g', 'a', 'e')
# ('d', 'g', 'a', 'f')
# ('d', 'g', 'a', 'h')
# ('d', 'g', 'a', 'i')
# ('d', 'g', 'a', 'j')
# ('d', 'g', 'b', 'a')
# ('d', 'g', 'b', 'c')
# ('d', 'g', 'b', 'e')
# ('d', 'g', 'b', 'f')
# ('d', 'g', 'b', 'h')
# ('d', 'g', 'b', 'i')
# ('d', 'g', 'b', 'j')
# ('d', 'g', 'c', 'a')
# ('d', 'g', 'c', 'b')
# ('d', 'g', 'c', 'e')
# ('d', 'g', 'c', 'f')
# ('d', 'g', 'c', 'h')
# ('d', 'g', 'c', 'i')
# ('d', 'g', 'c', 'j')
# ('d', 'g', 'e', 'a')
# ('d', 'g', 'e', 'b')
# ('d', 'g', 'e', 'c')
# ('d', 'g', 'e', 'f')
# ('d', 'g', 'e', 'h')
# ('d', 'g', 'e', 'i')
# ('d', 'g', 'e', 'j')
# ('d', 'g', 'f', 'a')
# ('d', 'g', 'f', 'b')
# ('d', 'g', 'f', 'c')
# ('d', 'g', 'f', 'e')
# ('d', 'g', 'f', 'h')
# ('d', 'g', 'f', 'i')
# ('d', 'g', 'f', 'j')
# ('d', 'g', 'h', 'a')
# ('d', 'g', 'h', 'b')
# ('d', 'g', 'h', 'c')
# ('d', 'g', 'h', 'e')
# ('d', 'g', 'h', 'f')
# ('d', 'g', 'h', 'i')
# ('d', 'g', 'h', 'j')
# ('d', 'g', 'i', 'a')
# ('d', 'g', 'i', 'b')
# ('d', 'g', 'i', 'c')
# ('d', 'g', 'i', 'e')
# ('d', 'g', 'i', 'f')
# ('d', 'g', 'i', 'h')
# ('d', 'g', 'i', 'j')
# ('d', 'g', 'j', 'a')
# ('d', 'g', 'j', 'b')
# ('d', 'g', 'j', 'c')
# ('d', 'g', 'j', 'e')
# ('d', 'g', 'j', 'f')
# ('d', 'g', 'j', 'h')
# ('d', 'g', 'j', 'i')
# ('d', 'h', 'a', 'b')
# ('d', 'h', 'a', 'c')
# ('d', 'h', 'a', 'e')
# ('d', 'h', 'a', 'f')
# ('d', 'h', 'a', 'g')
# ('d', 'h', 'a', 'i')
# ('d', 'h', 'a', 'j')
# ('d', 'h', 'b', 'a')
# ('d', 'h', 'b', 'c')
# ('d', 'h', 'b', 'e')
# ('d', 'h', 'b', 'f')
# ('d', 'h', 'b', 'g')
# ('d', 'h', 'b', 'i')
# ('d', 'h', 'b', 'j')
# ('d', 'h', 'c', 'a')
# ('d', 'h', 'c', 'b')
# ('d', 'h', 'c', 'e')
# ('d', 'h', 'c', 'f')
# ('d', 'h', 'c', 'g')
# ('d', 'h', 'c', 'i')
# ('d', 'h', 'c', 'j')
# ('d', 'h', 'e', 'a')
# ('d', 'h', 'e', 'b')
# ('d', 'h', 'e', 'c')
# ('d', 'h', 'e', 'f')
# ('d', 'h', 'e', 'g')
# ('d', 'h', 'e', 'i')
# ('d', 'h', 'e', 'j')
# ('d', 'h', 'f', 'a')
# ('d', 'h', 'f', 'b')
# ('d', 'h', 'f', 'c')
# ('d', 'h', 'f', 'e')
# ('d', 'h', 'f', 'g')
# ('d', 'h', 'f', 'i')
# ('d', 'h', 'f', 'j')
# ('d', 'h', 'g', 'a')
# ('d', 'h', 'g', 'b')
# ('d', 'h', 'g', 'c')
# ('d', 'h', 'g', 'e')
# ('d', 'h', 'g', 'f')
# ('d', 'h', 'g', 'i')
# ('d', 'h', 'g', 'j')
# ('d', 'h', 'i', 'a')
# ('d', 'h', 'i', 'b')
# ('d', 'h', 'i', 'c')
# ('d', 'h', 'i', 'e')
# ('d', 'h', 'i', 'f')
# ('d', 'h', 'i', 'g')
# ('d', 'h', 'i', 'j')
# ('d', 'h', 'j', 'a')
# ('d', 'h', 'j', 'b')
# ('d', 'h', 'j', 'c')
# ('d', 'h', 'j', 'e')
# ('d', 'h', 'j', 'f')
# ('d', 'h', 'j', 'g')
# ('d', 'h', 'j', 'i')
# ('d', 'i', 'a', 'b')
# ('d', 'i', 'a', 'c')
# ('d', 'i', 'a', 'e')
# ('d', 'i', 'a', 'f')
# ('d', 'i', 'a', 'g')
# ('d', 'i', 'a', 'h')
# ('d', 'i', 'a', 'j')
# ('d', 'i', 'b', 'a')
# ('d', 'i', 'b', 'c')
# ('d', 'i', 'b', 'e')
# ('d', 'i', 'b', 'f')
# ('d', 'i', 'b', 'g')
# ('d', 'i', 'b', 'h')
# ('d', 'i', 'b', 'j')
# ('d', 'i', 'c', 'a')
# ('d', 'i', 'c', 'b')
# ('d', 'i', 'c', 'e')
# ('d', 'i', 'c', 'f')
# ('d', 'i', 'c', 'g')
# ('d', 'i', 'c', 'h')
# ('d', 'i', 'c', 'j')
# ('d', 'i', 'e', 'a')
# ('d', 'i', 'e', 'b')
# ('d', 'i', 'e', 'c')
# ('d', 'i', 'e', 'f')
# ('d', 'i', 'e', 'g')
# ('d', 'i', 'e', 'h')
# ('d', 'i', 'e', 'j')
# ('d', 'i', 'f', 'a')
# ('d', 'i', 'f', 'b')
# ('d', 'i', 'f', 'c')
# ('d', 'i', 'f', 'e')
# ('d', 'i', 'f', 'g')
# ('d', 'i', 'f', 'h')
# ('d', 'i', 'f', 'j')
# ('d', 'i', 'g', 'a')
# ('d', 'i', 'g', 'b')
# ('d', 'i', 'g', 'c')
# ('d', 'i', 'g', 'e')
# ('d', 'i', 'g', 'f')
# ('d', 'i', 'g', 'h')
# ('d', 'i', 'g', 'j')
# ('d', 'i', 'h', 'a')
# ('d', 'i', 'h', 'b')
# ('d', 'i', 'h', 'c')
# ('d', 'i', 'h', 'e')
# ('d', 'i', 'h', 'f')
# ('d', 'i', 'h', 'g')
# ('d', 'i', 'h', 'j')
# ('d', 'i', 'j', 'a')
# ('d', 'i', 'j', 'b')
# ('d', 'i', 'j', 'c')
# ('d', 'i', 'j', 'e')
# ('d', 'i', 'j', 'f')
# ('d', 'i', 'j', 'g')
# ('d', 'i', 'j', 'h')
# ('d', 'j', 'a', 'b')
# ('d', 'j', 'a', 'c')
# ('d', 'j', 'a', 'e')
# ('d', 'j', 'a', 'f')
# ('d', 'j', 'a', 'g')
# ('d', 'j', 'a', 'h')
# ('d', 'j', 'a', 'i')
# ('d', 'j', 'b', 'a')
# ('d', 'j', 'b', 'c')
# ('d', 'j', 'b', 'e')
# ('d', 'j', 'b', 'f')
# ('d', 'j', 'b', 'g')
# ('d', 'j', 'b', 'h')
# ('d', 'j', 'b', 'i')
# ('d', 'j', 'c', 'a')
# ('d', 'j', 'c', 'b')
# ('d', 'j', 'c', 'e')
# ('d', 'j', 'c', 'f')
# ('d', 'j', 'c', 'g')
# ('d', 'j', 'c', 'h')
# ('d', 'j', 'c', 'i')
# ('d', 'j', 'e', 'a')
# ('d', 'j', 'e', 'b')
# ('d', 'j', 'e', 'c')
# ('d', 'j', 'e', 'f')
# ('d', 'j', 'e', 'g')
# ('d', 'j', 'e', 'h')
# ('d', 'j', 'e', 'i')
# ('d', 'j', 'f', 'a')
# ('d', 'j', 'f', 'b')
# ('d', 'j', 'f', 'c')
# ('d', 'j', 'f', 'e')
# ('d', 'j', 'f', 'g')
# ('d', 'j', 'f', 'h')
# ('d', 'j', 'f', 'i')
# ('d', 'j', 'g', 'a')
# ('d', 'j', 'g', 'b')
# ('d', 'j', 'g', 'c')
# ('d', 'j', 'g', 'e')
# ('d', 'j', 'g', 'f')
# ('d', 'j', 'g', 'h')
# ('d', 'j', 'g', 'i')
# ('d', 'j', 'h', 'a')
# ('d', 'j', 'h', 'b')
# ('d', 'j', 'h', 'c')
# ('d', 'j', 'h', 'e')
# ('d', 'j', 'h', 'f')
# ('d', 'j', 'h', 'g')
# ('d', 'j', 'h', 'i')
# ('d', 'j', 'i', 'a')
# ('d', 'j', 'i', 'b')
# ('d', 'j', 'i', 'c')
# ('d', 'j', 'i', 'e')
# ('d', 'j', 'i', 'f')
# ('d', 'j', 'i', 'g')
# ('d', 'j', 'i', 'h')
# ('e', 'a', 'b', 'c')
# ('e', 'a', 'b', 'd')
# ('e', 'a', 'b', 'f')
# ('e', 'a', 'b', 'g')
# ('e', 'a', 'b', 'h')
# ('e', 'a', 'b', 'i')
# ('e', 'a', 'b', 'j')
# ('e', 'a', 'c', 'b')
# ('e', 'a', 'c', 'd')
# ('e', 'a', 'c', 'f')
# ('e', 'a', 'c', 'g')
# ('e', 'a', 'c', 'h')
# ('e', 'a', 'c', 'i')
# ('e', 'a', 'c', 'j')
# ('e', 'a', 'd', 'b')
# ('e', 'a', 'd', 'c')
# ('e', 'a', 'd', 'f')
# ('e', 'a', 'd', 'g')
# ('e', 'a', 'd', 'h')
# ('e', 'a', 'd', 'i')
# ('e', 'a', 'd', 'j')
# ('e', 'a', 'f', 'b')
# ('e', 'a', 'f', 'c')
# ('e', 'a', 'f', 'd')
# ('e', 'a', 'f', 'g')
# ('e', 'a', 'f', 'h')
# ('e', 'a', 'f', 'i')
# ('e', 'a', 'f', 'j')
# ('e', 'a', 'g', 'b')
# ('e', 'a', 'g', 'c')
# ('e', 'a', 'g', 'd')
# ('e', 'a', 'g', 'f')
# ('e', 'a', 'g', 'h')
# ('e', 'a', 'g', 'i')
# ('e', 'a', 'g', 'j')
# ('e', 'a', 'h', 'b')
# ('e', 'a', 'h', 'c')
# ('e', 'a', 'h', 'd')
# ('e', 'a', 'h', 'f')
# ('e', 'a', 'h', 'g')
# ('e', 'a', 'h', 'i')
# ('e', 'a', 'h', 'j')
# ('e', 'a', 'i', 'b')
# ('e', 'a', 'i', 'c')
# ('e', 'a', 'i', 'd')
# ('e', 'a', 'i', 'f')
# ('e', 'a', 'i', 'g')
# ('e', 'a', 'i', 'h')
# ('e', 'a', 'i', 'j')
# ('e', 'a', 'j', 'b')
# ('e', 'a', 'j', 'c')
# ('e', 'a', 'j', 'd')
# ('e', 'a', 'j', 'f')
# ('e', 'a', 'j', 'g')
# ('e', 'a', 'j', 'h')
# ('e', 'a', 'j', 'i')
# ('e', 'b', 'a', 'c')
# ('e', 'b', 'a', 'd')
# ('e', 'b', 'a', 'f')
# ('e', 'b', 'a', 'g')
# ('e', 'b', 'a', 'h')
# ('e', 'b', 'a', 'i')
# ('e', 'b', 'a', 'j')
# ('e', 'b', 'c', 'a')
# ('e', 'b', 'c', 'd')
# ('e', 'b', 'c', 'f')
# ('e', 'b', 'c', 'g')
# ('e', 'b', 'c', 'h')
# ('e', 'b', 'c', 'i')
# ('e', 'b', 'c', 'j')
# ('e', 'b', 'd', 'a')
# ('e', 'b', 'd', 'c')
# ('e', 'b', 'd', 'f')
# ('e', 'b', 'd', 'g')
# ('e', 'b', 'd', 'h')
# ('e', 'b', 'd', 'i')
# ('e', 'b', 'd', 'j')
# ('e', 'b', 'f', 'a')
# ('e', 'b', 'f', 'c')
# ('e', 'b', 'f', 'd')
# ('e', 'b', 'f', 'g')
# ('e', 'b', 'f', 'h')
# ('e', 'b', 'f', 'i')
# ('e', 'b', 'f', 'j')
# ('e', 'b', 'g', 'a')
# ('e', 'b', 'g', 'c')
# ('e', 'b', 'g', 'd')
# ('e', 'b', 'g', 'f')
# ('e', 'b', 'g', 'h')
# ('e', 'b', 'g', 'i')
# ('e', 'b', 'g', 'j')
# ('e', 'b', 'h', 'a')
# ('e', 'b', 'h', 'c')
# ('e', 'b', 'h', 'd')
# ('e', 'b', 'h', 'f')
# ('e', 'b', 'h', 'g')
# ('e', 'b', 'h', 'i')
# ('e', 'b', 'h', 'j')
# ('e', 'b', 'i', 'a')
# ('e', 'b', 'i', 'c')
# ('e', 'b', 'i', 'd')
# ('e', 'b', 'i', 'f')
# ('e', 'b', 'i', 'g')
# ('e', 'b', 'i', 'h')
# ('e', 'b', 'i', 'j')
# ('e', 'b', 'j', 'a')
# ('e', 'b', 'j', 'c')
# ('e', 'b', 'j', 'd')
# ('e', 'b', 'j', 'f')
# ('e', 'b', 'j', 'g')
# ('e', 'b', 'j', 'h')
# ('e', 'b', 'j', 'i')
# ('e', 'c', 'a', 'b')
# ('e', 'c', 'a', 'd')
# ('e', 'c', 'a', 'f')
# ('e', 'c', 'a', 'g')
# ('e', 'c', 'a', 'h')
# ('e', 'c', 'a', 'i')
# ('e', 'c', 'a', 'j')
# ('e', 'c', 'b', 'a')
# ('e', 'c', 'b', 'd')
# ('e', 'c', 'b', 'f')
# ('e', 'c', 'b', 'g')
# ('e', 'c', 'b', 'h')
# ('e', 'c', 'b', 'i')
# ('e', 'c', 'b', 'j')
# ('e', 'c', 'd', 'a')
# ('e', 'c', 'd', 'b')
# ('e', 'c', 'd', 'f')
# ('e', 'c', 'd', 'g')
# ('e', 'c', 'd', 'h')
# ('e', 'c', 'd', 'i')
# ('e', 'c', 'd', 'j')
# ('e', 'c', 'f', 'a')
# ('e', 'c', 'f', 'b')
# ('e', 'c', 'f', 'd')
# ('e', 'c', 'f', 'g')
# ('e', 'c', 'f', 'h')
# ('e', 'c', 'f', 'i')
# ('e', 'c', 'f', 'j')
# ('e', 'c', 'g', 'a')
# ('e', 'c', 'g', 'b')
# ('e', 'c', 'g', 'd')
# ('e', 'c', 'g', 'f')
# ('e', 'c', 'g', 'h')
# ('e', 'c', 'g', 'i')
# ('e', 'c', 'g', 'j')
# ('e', 'c', 'h', 'a')
# ('e', 'c', 'h', 'b')
# ('e', 'c', 'h', 'd')
# ('e', 'c', 'h', 'f')
# ('e', 'c', 'h', 'g')
# ('e', 'c', 'h', 'i')
# ('e', 'c', 'h', 'j')
# ('e', 'c', 'i', 'a')
# ('e', 'c', 'i', 'b')
# ('e', 'c', 'i', 'd')
# ('e', 'c', 'i', 'f')
# ('e', 'c', 'i', 'g')
# ('e', 'c', 'i', 'h')
# ('e', 'c', 'i', 'j')
# ('e', 'c', 'j', 'a')
# ('e', 'c', 'j', 'b')
# ('e', 'c', 'j', 'd')
# ('e', 'c', 'j', 'f')
# ('e', 'c', 'j', 'g')
# ('e', 'c', 'j', 'h')
# ('e', 'c', 'j', 'i')
# ('e', 'd', 'a', 'b')
# ('e', 'd', 'a', 'c')
# ('e', 'd', 'a', 'f')
# ('e', 'd', 'a', 'g')
# ('e', 'd', 'a', 'h')
# ('e', 'd', 'a', 'i')
# ('e', 'd', 'a', 'j')
# ('e', 'd', 'b', 'a')
# ('e', 'd', 'b', 'c')
# ('e', 'd', 'b', 'f')
# ('e', 'd', 'b', 'g')
# ('e', 'd', 'b', 'h')
# ('e', 'd', 'b', 'i')
# ('e', 'd', 'b', 'j')
# ('e', 'd', 'c', 'a')
# ('e', 'd', 'c', 'b')
# ('e', 'd', 'c', 'f')
# ('e', 'd', 'c', 'g')
# ('e', 'd', 'c', 'h')
# ('e', 'd', 'c', 'i')
# ('e', 'd', 'c', 'j')
# ('e', 'd', 'f', 'a')
# ('e', 'd', 'f', 'b')
# ('e', 'd', 'f', 'c')
# ('e', 'd', 'f', 'g')
# ('e', 'd', 'f', 'h')
# ('e', 'd', 'f', 'i')
# ('e', 'd', 'f', 'j')
# ('e', 'd', 'g', 'a')
# ('e', 'd', 'g', 'b')
# ('e', 'd', 'g', 'c')
# ('e', 'd', 'g', 'f')
# ('e', 'd', 'g', 'h')
# ('e', 'd', 'g', 'i')
# ('e', 'd', 'g', 'j')
# ('e', 'd', 'h', 'a')
# ('e', 'd', 'h', 'b')
# ('e', 'd', 'h', 'c')
# ('e', 'd', 'h', 'f')
# ('e', 'd', 'h', 'g')
# ('e', 'd', 'h', 'i')
# ('e', 'd', 'h', 'j')
# ('e', 'd', 'i', 'a')
# ('e', 'd', 'i', 'b')
# ('e', 'd', 'i', 'c')
# ('e', 'd', 'i', 'f')
# ('e', 'd', 'i', 'g')
# ('e', 'd', 'i', 'h')
# ('e', 'd', 'i', 'j')
# ('e', 'd', 'j', 'a')
# ('e', 'd', 'j', 'b')
# ('e', 'd', 'j', 'c')
# ('e', 'd', 'j', 'f')
# ('e', 'd', 'j', 'g')
# ('e', 'd', 'j', 'h')
# ('e', 'd', 'j', 'i')
# ('e', 'f', 'a', 'b')
# ('e', 'f', 'a', 'c')
# ('e', 'f', 'a', 'd')
# ('e', 'f', 'a', 'g')
# ('e', 'f', 'a', 'h')
# ('e', 'f', 'a', 'i')
# ('e', 'f', 'a', 'j')
# ('e', 'f', 'b', 'a')
# ('e', 'f', 'b', 'c')
# ('e', 'f', 'b', 'd')
# ('e', 'f', 'b', 'g')
# ('e', 'f', 'b', 'h')
# ('e', 'f', 'b', 'i')
# ('e', 'f', 'b', 'j')
# ('e', 'f', 'c', 'a')
# ('e', 'f', 'c', 'b')
# ('e', 'f', 'c', 'd')
# ('e', 'f', 'c', 'g')
# ('e', 'f', 'c', 'h')
# ('e', 'f', 'c', 'i')
# ('e', 'f', 'c', 'j')
# ('e', 'f', 'd', 'a')
# ('e', 'f', 'd', 'b')
# ('e', 'f', 'd', 'c')
# ('e', 'f', 'd', 'g')
# ('e', 'f', 'd', 'h')
# ('e', 'f', 'd', 'i')
# ('e', 'f', 'd', 'j')
# ('e', 'f', 'g', 'a')
# ('e', 'f', 'g', 'b')
# ('e', 'f', 'g', 'c')
# ('e', 'f', 'g', 'd')
# ('e', 'f', 'g', 'h')
# ('e', 'f', 'g', 'i')
# ('e', 'f', 'g', 'j')
# ('e', 'f', 'h', 'a')
# ('e', 'f', 'h', 'b')
# ('e', 'f', 'h', 'c')
# ('e', 'f', 'h', 'd')
# ...
# ('i', 'e', 'd', 'c')
# ('i', 'e', 'd', 'f')
# ('i', 'e', 'd', 'g')
# ('i', 'e', 'd', 'h')
# ('i', 'e', 'd', 'j')
# ('i', 'e', 'f', 'a')
# ('i', 'e', 'f', 'b')
# ('i', 'e', 'f', 'c')
# ('i', 'e', 'f', 'd')
# ('i', 'e', 'f', 'g')
# ('i', 'e', 'f', 'h')
# ('i', 'e', 'f', 'j')
# ('i', 'e', 'g', 'a')
# ('i', 'e', 'g', 'b')
# ('i', 'e', 'g', 'c')
# ('i', 'e', 'g', 'd')
# ('i', 'e', 'g', 'f')
# ('i', 'e', 'g', 'h')
# ('i', 'e', 'g', 'j')
# ('i', 'e', 'h', 'a')
# ('i', 'e', 'h', 'b')
# ('i', 'e', 'h', 'c')
# ('i', 'e', 'h', 'd')
# ('i', 'e', 'h', 'f')
# ('i', 'e', 'h', 'g')
# ('i', 'e', 'h', 'j')
# ('i', 'e', 'j', 'a')
# ('i', 'e', 'j', 'b')
# ('i', 'e', 'j', 'c')
# ('i', 'e', 'j', 'd')
# ('i', 'e', 'j', 'f')
# ('i', 'e', 'j', 'g')
# ('i', 'e', 'j', 'h')
# ('i', 'f', 'a', 'b')
# ('i', 'f', 'a', 'c')
# ('i', 'f', 'a', 'd')
# ('i', 'f', 'a', 'e')
# ('i', 'f', 'a', 'g')
# ('i', 'f', 'a', 'h')
# ('i', 'f', 'a', 'j')
# ('i', 'f', 'b', 'a')
# ('i', 'f', 'b', 'c')
# ('i', 'f', 'b', 'd')
# ('i', 'f', 'b', 'e')
# ('i', 'f', 'b', 'g')
# ('i', 'f', 'b', 'h')
# ('i', 'f', 'b', 'j')
# ('i', 'f', 'c', 'a')
# ('i', 'f', 'c', 'b')
# ('i', 'f', 'c', 'd')
# ('i', 'f', 'c', 'e')
# ('i', 'f', 'c', 'g')
# ('i', 'f', 'c', 'h')
# ('i', 'f', 'c', 'j')
# ('i', 'f', 'd', 'a')
# ('i', 'f', 'd', 'b')
# ('i', 'f', 'd', 'c')
# ('i', 'f', 'd', 'e')
# ('i', 'f', 'd', 'g')
# ('i', 'f', 'd', 'h')
# ('i', 'f', 'd', 'j')
# ('i', 'f', 'e', 'a')
# ('i', 'f', 'e', 'b')
# ('i', 'f', 'e', 'c')
# ('i', 'f', 'e', 'd')
# ('i', 'f', 'e', 'g')
# ('i', 'f', 'e', 'h')
# ('i', 'f', 'e', 'j')
# ('i', 'f', 'g', 'a')
# ('i', 'f', 'g', 'b')
# ('i', 'f', 'g', 'c')
# ('i', 'f', 'g', 'd')
# ('i', 'f', 'g', 'e')
# ('i', 'f', 'g', 'h')
# ('i', 'f', 'g', 'j')
# ('i', 'f', 'h', 'a')
# ('i', 'f', 'h', 'b')
# ('i', 'f', 'h', 'c')
# ('i', 'f', 'h', 'd')
# ('i', 'f', 'h', 'e')
# ('i', 'f', 'h', 'g')
# ('i', 'f', 'h', 'j')
# ('i', 'f', 'j', 'a')
# ('i', 'f', 'j', 'b')
# ('i', 'f', 'j', 'c')
# ('i', 'f', 'j', 'd')
# ('i', 'f', 'j', 'e')
# ('i', 'f', 'j', 'g')
# ('i', 'f', 'j', 'h')
# ('i', 'g', 'a', 'b')
# ('i', 'g', 'a', 'c')
# ('i', 'g', 'a', 'd')
# ('i', 'g', 'a', 'e')
# ('i', 'g', 'a', 'f')
# ('i', 'g', 'a', 'h')
# ('i', 'g', 'a', 'j')
# ('i', 'g', 'b', 'a')
# ('i', 'g', 'b', 'c')
# ('i', 'g', 'b', 'd')
# ('i', 'g', 'b', 'e')
# ('i', 'g', 'b', 'f')
# ('i', 'g', 'b', 'h')
# ('i', 'g', 'b', 'j')
# ('i', 'g', 'c', 'a')
# ('i', 'g', 'c', 'b')
# ('i', 'g', 'c', 'd')
# ('i', 'g', 'c', 'e')
# ('i', 'g', 'c', 'f')
# ('i', 'g', 'c', 'h')
# ('i', 'g', 'c', 'j')
# ('i', 'g', 'd', 'a')
# ('i', 'g', 'd', 'b')
# ('i', 'g', 'd', 'c')
# ('i', 'g', 'd', 'e')
# ('i', 'g', 'd', 'f')
# ('i', 'g', 'd', 'h')
# ('i', 'g', 'd', 'j')
# ('i', 'g', 'e', 'a')
# ('i', 'g', 'e', 'b')
# ('i', 'g', 'e', 'c')
# ('i', 'g', 'e', 'd')
# ('i', 'g', 'e', 'f')
# ('i', 'g', 'e', 'h')
# ('i', 'g', 'e', 'j')
# ('i', 'g', 'f', 'a')
# ('i', 'g', 'f', 'b')
# ('i', 'g', 'f', 'c')
# ('i', 'g', 'f', 'd')
# ('i', 'g', 'f', 'e')
# ('i', 'g', 'f', 'h')
# ('i', 'g', 'f', 'j')
# ('i', 'g', 'h', 'a')
# ('i', 'g', 'h', 'b')
# ('i', 'g', 'h', 'c')
# ('i', 'g', 'h', 'd')
# ('i', 'g', 'h', 'e')
# ('i', 'g', 'h', 'f')
# ('i', 'g', 'h', 'j')
# ('i', 'g', 'j', 'a')
# ('i', 'g', 'j', 'b')
# ('i', 'g', 'j', 'c')
# ('i', 'g', 'j', 'd')
# ('i', 'g', 'j', 'e')
# ('i', 'g', 'j', 'f')
# ('i', 'g', 'j', 'h')
# ('i', 'h', 'a', 'b')
# ('i', 'h', 'a', 'c')
# ('i', 'h', 'a', 'd')
# ('i', 'h', 'a', 'e')
# ('i', 'h', 'a', 'f')
# ('i', 'h', 'a', 'g')
# ('i', 'h', 'a', 'j')
# ('i', 'h', 'b', 'a')
# ('i', 'h', 'b', 'c')
# ('i', 'h', 'b', 'd')
# ('i', 'h', 'b', 'e')
# ('i', 'h', 'b', 'f')
# ('i', 'h', 'b', 'g')
# ('i', 'h', 'b', 'j')
# ('i', 'h', 'c', 'a')
# ('i', 'h', 'c', 'b')
# ('i', 'h', 'c', 'd')
# ('i', 'h', 'c', 'e')
# ('i', 'h', 'c', 'f')
# ('i', 'h', 'c', 'g')
# ('i', 'h', 'c', 'j')
# ('i', 'h', 'd', 'a')
# ('i', 'h', 'd', 'b')
# ('i', 'h', 'd', 'c')
# ('i', 'h', 'd', 'e')
# ('i', 'h', 'd', 'f')
# ('i', 'h', 'd', 'g')
# ('i', 'h', 'd', 'j')
# ('i', 'h', 'e', 'a')
# ('i', 'h', 'e', 'b')
# ('i', 'h', 'e', 'c')
# ('i', 'h', 'e', 'd')
# ('i', 'h', 'e', 'f')
# ('i', 'h', 'e', 'g')
# ('i', 'h', 'e', 'j')
# ('i', 'h', 'f', 'a')
# ('i', 'h', 'f', 'b')
# ('i', 'h', 'f', 'c')
# ('i', 'h', 'f', 'd')
# ('i', 'h', 'f', 'e')
# ('i', 'h', 'f', 'g')
# ('i', 'h', 'f', 'j')
# ('i', 'h', 'g', 'a')
# ('i', 'h', 'g', 'b')
# ('i', 'h', 'g', 'c')
# ('i', 'h', 'g', 'd')
# ('i', 'h', 'g', 'e')
# ('i', 'h', 'g', 'f')
# ('i', 'h', 'g', 'j')
# ('i', 'h', 'j', 'a')
# ('i', 'h', 'j', 'b')
# ('i', 'h', 'j', 'c')
# ('i', 'h', 'j', 'd')
# ('i', 'h', 'j', 'e')
# ('i', 'h', 'j', 'f')
# ('i', 'h', 'j', 'g')
# ('i', 'j', 'a', 'b')
# ('i', 'j', 'a', 'c')
# ('i', 'j', 'a', 'd')
# ('i', 'j', 'a', 'e')
# ('i', 'j', 'a', 'f')
# ('i', 'j', 'a', 'g')
# ('i', 'j', 'a', 'h')
# ('i', 'j', 'b', 'a')
# ('i', 'j', 'b', 'c')
# ('i', 'j', 'b', 'd')
# ('i', 'j', 'b', 'e')
# ('i', 'j', 'b', 'f')
# ('i', 'j', 'b', 'g')
# ('i', 'j', 'b', 'h')
# ('i', 'j', 'c', 'a')
# ('i', 'j', 'c', 'b')
# ('i', 'j', 'c', 'd')
# ('i', 'j', 'c', 'e')
# ('i', 'j', 'c', 'f')
# ('i', 'j', 'c', 'g')
# ('i', 'j', 'c', 'h')
# ('i', 'j', 'd', 'a')
# ('i', 'j', 'd', 'b')
# ('i', 'j', 'd', 'c')
# ('i', 'j', 'd', 'e')
# ('i', 'j', 'd', 'f')
# ('i', 'j', 'd', 'g')
# ('i', 'j', 'd', 'h')
# ('i', 'j', 'e', 'a')
# ('i', 'j', 'e', 'b')
# ('i', 'j', 'e', 'c')
# ('i', 'j', 'e', 'd')
# ('i', 'j', 'e', 'f')
# ('i', 'j', 'e', 'g')
# ('i', 'j', 'e', 'h')
# ('i', 'j', 'f', 'a')
# ('i', 'j', 'f', 'b')
# ('i', 'j', 'f', 'c')
# ('i', 'j', 'f', 'd')
# ('i', 'j', 'f', 'e')
# ('i', 'j', 'f', 'g')
# ('i', 'j', 'f', 'h')
# ('i', 'j', 'g', 'a')
# ('i', 'j', 'g', 'b')
# ('i', 'j', 'g', 'c')
# ('i', 'j', 'g', 'd')
# ('i', 'j', 'g', 'e')
# ('i', 'j', 'g', 'f')
# ('i', 'j', 'g', 'h')
# ('i', 'j', 'h', 'a')
# ('i', 'j', 'h', 'b')
# ('i', 'j', 'h', 'c')
# ('i', 'j', 'h', 'd')
# ('i', 'j', 'h', 'e')
# ('i', 'j', 'h', 'f')
# ('i', 'j', 'h', 'g')
# ('j', 'a', 'b', 'c')
# ('j', 'a', 'b', 'd')
# ('j', 'a', 'b', 'e')
# ('j', 'a', 'b', 'f')
# ('j', 'a', 'b', 'g')
# ('j', 'a', 'b', 'h')
# ('j', 'a', 'b', 'i')
# ('j', 'a', 'c', 'b')
# ('j', 'a', 'c', 'd')
# ('j', 'a', 'c', 'e')
# ('j', 'a', 'c', 'f')
# ('j', 'a', 'c', 'g')
# ('j', 'a', 'c', 'h')
# ('j', 'a', 'c', 'i')
# ('j', 'a', 'd', 'b')
# ('j', 'a', 'd', 'c')
# ('j', 'a', 'd', 'e')
# ('j', 'a', 'd', 'f')
# ('j', 'a', 'd', 'g')
# ('j', 'a', 'd', 'h')
# ('j', 'a', 'd', 'i')
# ('j', 'a', 'e', 'b')
# ('j', 'a', 'e', 'c')
# ('j', 'a', 'e', 'd')
# ('j', 'a', 'e', 'f')
# ('j', 'a', 'e', 'g')
# ('j', 'a', 'e', 'h')
# ('j', 'a', 'e', 'i')
# ('j', 'a', 'f', 'b')
# ('j', 'a', 'f', 'c')
# ('j', 'a', 'f', 'd')
# ('j', 'a', 'f', 'e')
# ('j', 'a', 'f', 'g')
# ('j', 'a', 'f', 'h')
# ('j', 'a', 'f', 'i')
# ('j', 'a', 'g', 'b')
# ('j', 'a', 'g', 'c')
# ('j', 'a', 'g', 'd')
# ('j', 'a', 'g', 'e')
# ('j', 'a', 'g', 'f')
# ('j', 'a', 'g', 'h')
# ('j', 'a', 'g', 'i')
# ('j', 'a', 'h', 'b')
# ('j', 'a', 'h', 'c')
# ('j', 'a', 'h', 'd')
# ('j', 'a', 'h', 'e')
# ('j', 'a', 'h', 'f')
# ('j', 'a', 'h', 'g')
# ('j', 'a', 'h', 'i')
# ('j', 'a', 'i', 'b')
# ('j', 'a', 'i', 'c')
# ('j', 'a', 'i', 'd')
# ('j', 'a', 'i', 'e')
# ('j', 'a', 'i', 'f')
# ('j', 'a', 'i', 'g')
# ('j', 'a', 'i', 'h')
# ('j', 'b', 'a', 'c')
# ('j', 'b', 'a', 'd')
# ('j', 'b', 'a', 'e')
# ('j', 'b', 'a', 'f')
# ('j', 'b', 'a', 'g')
# ('j', 'b', 'a', 'h')
# ('j', 'b', 'a', 'i')
# ('j', 'b', 'c', 'a')
# ('j', 'b', 'c', 'd')
# ('j', 'b', 'c', 'e')
# ('j', 'b', 'c', 'f')
# ('j', 'b', 'c', 'g')
# ('j', 'b', 'c', 'h')
# ('j', 'b', 'c', 'i')
# ('j', 'b', 'd', 'a')
# ('j', 'b', 'd', 'c')
# ('j', 'b', 'd', 'e')
# ('j', 'b', 'd', 'f')
# ('j', 'b', 'd', 'g')
# ('j', 'b', 'd', 'h')
# ('j', 'b', 'd', 'i')
# ('j', 'b', 'e', 'a')
# ('j', 'b', 'e', 'c')
# ('j', 'b', 'e', 'd')
# ('j', 'b', 'e', 'f')
# ('j', 'b', 'e', 'g')
# ('j', 'b', 'e', 'h')
# ('j', 'b', 'e', 'i')
# ('j', 'b', 'f', 'a')
# ('j', 'b', 'f', 'c')
# ('j', 'b', 'f', 'd')
# ('j', 'b', 'f', 'e')
# ('j', 'b', 'f', 'g')
# ('j', 'b', 'f', 'h')
# ('j', 'b', 'f', 'i')
# ('j', 'b', 'g', 'a')
# ('j', 'b', 'g', 'c')
# ('j', 'b', 'g', 'd')
# ('j', 'b', 'g', 'e')
# ('j', 'b', 'g', 'f')
# ('j', 'b', 'g', 'h')
# ('j', 'b', 'g', 'i')
# ('j', 'b', 'h', 'a')
# ('j', 'b', 'h', 'c')
# ('j', 'b', 'h', 'd')
# ('j', 'b', 'h', 'e')
# ('j', 'b', 'h', 'f')
# ('j', 'b', 'h', 'g')
# ('j', 'b', 'h', 'i')
# ('j', 'b', 'i', 'a')
# ('j', 'b', 'i', 'c')
# ('j', 'b', 'i', 'd')
# ('j', 'b', 'i', 'e')
# ('j', 'b', 'i', 'f')
# ('j', 'b', 'i', 'g')
# ('j', 'b', 'i', 'h')
# ('j', 'c', 'a', 'b')
# ('j', 'c', 'a', 'd')
# ('j', 'c', 'a', 'e')
# ('j', 'c', 'a', 'f')
# ('j', 'c', 'a', 'g')
# ('j', 'c', 'a', 'h')
# ('j', 'c', 'a', 'i')
# ('j', 'c', 'b', 'a')
# ('j', 'c', 'b', 'd')
# ('j', 'c', 'b', 'e')
# ('j', 'c', 'b', 'f')
# ('j', 'c', 'b', 'g')
# ('j', 'c', 'b', 'h')
# ('j', 'c', 'b', 'i')
# ('j', 'c', 'd', 'a')
# ('j', 'c', 'd', 'b')
# ('j', 'c', 'd', 'e')
# ('j', 'c', 'd', 'f')
# ('j', 'c', 'd', 'g')
# ('j', 'c', 'd', 'h')
# ('j', 'c', 'd', 'i')
# ('j', 'c', 'e', 'a')
# ('j', 'c', 'e', 'b')
# ('j', 'c', 'e', 'd')
# ('j', 'c', 'e', 'f')
# ('j', 'c', 'e', 'g')
# ('j', 'c', 'e', 'h')
# ('j', 'c', 'e', 'i')
# ('j', 'c', 'f', 'a')
# ('j', 'c', 'f', 'b')
# ('j', 'c', 'f', 'd')
# ('j', 'c', 'f', 'e')
# ('j', 'c', 'f', 'g')
# ('j', 'c', 'f', 'h')
# ('j', 'c', 'f', 'i')
# ('j', 'c', 'g', 'a')
# ('j', 'c', 'g', 'b')
# ('j', 'c', 'g', 'd')
# ('j', 'c', 'g', 'e')
# ('j', 'c', 'g', 'f')
# ('j', 'c', 'g', 'h')
# ('j', 'c', 'g', 'i')
# ('j', 'c', 'h', 'a')
# ('j', 'c', 'h', 'b')
# ('j', 'c', 'h', 'd')
# ('j', 'c', 'h', 'e')
# ('j', 'c', 'h', 'f')
# ('j', 'c', 'h', 'g')
# ('j', 'c', 'h', 'i')
# ('j', 'c', 'i', 'a')
# ('j', 'c', 'i', 'b')
# ('j', 'c', 'i', 'd')
# ('j', 'c', 'i', 'e')
# ('j', 'c', 'i', 'f')
# ('j', 'c', 'i', 'g')
# ('j', 'c', 'i', 'h')
# ('j', 'd', 'a', 'b')
# ('j', 'd', 'a', 'c')
# ('j', 'd', 'a', 'e')
# ('j', 'd', 'a', 'f')
# ('j', 'd', 'a', 'g')
# ('j', 'd', 'a', 'h')
# ('j', 'd', 'a', 'i')
# ('j', 'd', 'b', 'a')
# ('j', 'd', 'b', 'c')
# ('j', 'd', 'b', 'e')
# ('j', 'd', 'b', 'f')
# ('j', 'd', 'b', 'g')
# ('j', 'd', 'b', 'h')
# ('j', 'd', 'b', 'i')
# ('j', 'd', 'c', 'a')
# ('j', 'd', 'c', 'b')
# ('j', 'd', 'c', 'e')
# ('j', 'd', 'c', 'f')
# ('j', 'd', 'c', 'g')
# ('j', 'd', 'c', 'h')
# ('j', 'd', 'c', 'i')
# ('j', 'd', 'e', 'a')
# ('j', 'd', 'e', 'b')
# ('j', 'd', 'e', 'c')
# ('j', 'd', 'e', 'f')
# ('j', 'd', 'e', 'g')
# ('j', 'd', 'e', 'h')
# ('j', 'd', 'e', 'i')
# ('j', 'd', 'f', 'a')
# ('j', 'd', 'f', 'b')
# ('j', 'd', 'f', 'c')
# ('j', 'd', 'f', 'e')
# ('j', 'd', 'f', 'g')
# ('j', 'd', 'f', 'h')
# ('j', 'd', 'f', 'i')
# ('j', 'd', 'g', 'a')
# ('j', 'd', 'g', 'b')
# ('j', 'd', 'g', 'c')
# ('j', 'd', 'g', 'e')
# ('j', 'd', 'g', 'f')
# ('j', 'd', 'g', 'h')
# ('j', 'd', 'g', 'i')
# ('j', 'd', 'h', 'a')
# ('j', 'd', 'h', 'b')
# ('j', 'd', 'h', 'c')
# ('j', 'd', 'h', 'e')
# ('j', 'd', 'h', 'f')
# ('j', 'd', 'h', 'g')
# ('j', 'd', 'h', 'i')
# ('j', 'd', 'i', 'a')
# ('j', 'd', 'i', 'b')
# ('j', 'd', 'i', 'c')
# ('j', 'd', 'i', 'e')
# ('j', 'd', 'i', 'f')
# ('j', 'd', 'i', 'g')
# ('j', 'd', 'i', 'h')
# ('j', 'e', 'a', 'b')
# ('j', 'e', 'a', 'c')
# ('j', 'e', 'a', 'd')
# ('j', 'e', 'a', 'f')
# ('j', 'e', 'a', 'g')
# ('j', 'e', 'a', 'h')
# ('j', 'e', 'a', 'i')
# ('j', 'e', 'b', 'a')
# ('j', 'e', 'b', 'c')
# ('j', 'e', 'b', 'd')
# ('j', 'e', 'b', 'f')
# ('j', 'e', 'b', 'g')
# ('j', 'e', 'b', 'h')
# ('j', 'e', 'b', 'i')
# ('j', 'e', 'c', 'a')
# ('j', 'e', 'c', 'b')
# ('j', 'e', 'c', 'd')
# ('j', 'e', 'c', 'f')
# ('j', 'e', 'c', 'g')
# ('j', 'e', 'c', 'h')
# ('j', 'e', 'c', 'i')
# ('j', 'e', 'd', 'a')
# ('j', 'e', 'd', 'b')
# ('j', 'e', 'd', 'c')
# ('j', 'e', 'd', 'f')
# ('j', 'e', 'd', 'g')
# ('j', 'e', 'd', 'h')
# ('j', 'e', 'd', 'i')
# ('j', 'e', 'f', 'a')
# ('j', 'e', 'f', 'b')
# ('j', 'e', 'f', 'c')
# ('j', 'e', 'f', 'd')
# ('j', 'e', 'f', 'g')
# ('j', 'e', 'f', 'h')
# ('j', 'e', 'f', 'i')
# ('j', 'e', 'g', 'a')
# ('j', 'e', 'g', 'b')
# ('j', 'e', 'g', 'c')
# ('j', 'e', 'g', 'd')
# ('j', 'e', 'g', 'f')
# ('j', 'e', 'g', 'h')
# ('j', 'e', 'g', 'i')
# ('j', 'e', 'h', 'a')
# ('j', 'e', 'h', 'b')
# ('j', 'e', 'h', 'c')
# ('j', 'e', 'h', 'd')
# ('j', 'e', 'h', 'f')
# ('j', 'e', 'h', 'g')
# ('j', 'e', 'h', 'i')
# ('j', 'e', 'i', 'a')
# ('j', 'e', 'i', 'b')
# ('j', 'e', 'i', 'c')
# ('j', 'e', 'i', 'd')
# ('j', 'e', 'i', 'f')
# ('j', 'e', 'i', 'g')
# ('j', 'e', 'i', 'h')
# ('j', 'f', 'a', 'b')
# ('j', 'f', 'a', 'c')
# ('j', 'f', 'a', 'd')
# ('j', 'f', 'a', 'e')
# ('j', 'f', 'a', 'g')
# ('j', 'f', 'a', 'h')
# ('j', 'f', 'a', 'i')
# ('j', 'f', 'b', 'a')
# ('j', 'f', 'b', 'c')
# ('j', 'f', 'b', 'd')
# ('j', 'f', 'b', 'e')
# ('j', 'f', 'b', 'g')
# ('j', 'f', 'b', 'h')
# ('j', 'f', 'b', 'i')
# ('j', 'f', 'c', 'a')
# ('j', 'f', 'c', 'b')
# ('j', 'f', 'c', 'd')
# ('j', 'f', 'c', 'e')
# ('j', 'f', 'c', 'g')
# ('j', 'f', 'c', 'h')
# ('j', 'f', 'c', 'i')
# ('j', 'f', 'd', 'a')
# ('j', 'f', 'd', 'b')
# ('j', 'f', 'd', 'c')
# ('j', 'f', 'd', 'e')
# ('j', 'f', 'd', 'g')
# ('j', 'f', 'd', 'h')
# ('j', 'f', 'd', 'i')
# ('j', 'f', 'e', 'a')
# ('j', 'f', 'e', 'b')
# ('j', 'f', 'e', 'c')
# ('j', 'f', 'e', 'd')
# ('j', 'f', 'e', 'g')
# ('j', 'f', 'e', 'h')
# ('j', 'f', 'e', 'i')
# ('j', 'f', 'g', 'a')
# ('j', 'f', 'g', 'b')
# ('j', 'f', 'g', 'c')
# ('j', 'f', 'g', 'd')
# ('j', 'f', 'g', 'e')
# ('j', 'f', 'g', 'h')
# ('j', 'f', 'g', 'i')
# ('j', 'f', 'h', 'a')
# ('j', 'f', 'h', 'b')
# ('j', 'f', 'h', 'c')
# ('j', 'f', 'h', 'd')
# ('j', 'f', 'h', 'e')
# ('j', 'f', 'h', 'g')
# ('j', 'f', 'h', 'i')
# ('j', 'f', 'i', 'a')
# ('j', 'f', 'i', 'b')
# ('j', 'f', 'i', 'c')
# ('j', 'f', 'i', 'd')
# ('j', 'f', 'i', 'e')
# ('j', 'f', 'i', 'g')
# ('j', 'f', 'i', 'h')
# ('j', 'g', 'a', 'b')
# ('j', 'g', 'a', 'c')
# ('j', 'g', 'a', 'd')
# ('j', 'g', 'a', 'e')
# ('j', 'g', 'a', 'f')
# ('j', 'g', 'a', 'h')
# ('j', 'g', 'a', 'i')
# ('j', 'g', 'b', 'a')
# ('j', 'g', 'b', 'c')
# ('j', 'g', 'b', 'd')
# ('j', 'g', 'b', 'e')
# ('j', 'g', 'b', 'f')
# ('j', 'g', 'b', 'h')
# ('j', 'g', 'b', 'i')
# ('j', 'g', 'c', 'a')
# ('j', 'g', 'c', 'b')
# ('j', 'g', 'c', 'd')
# ('j', 'g', 'c', 'e')
# ('j', 'g', 'c', 'f')
# ('j', 'g', 'c', 'h')
# ('j', 'g', 'c', 'i')
# ('j', 'g', 'd', 'a')
# ('j', 'g', 'd', 'b')
# ('j', 'g', 'd', 'c')
# ('j', 'g', 'd', 'e')
# ('j', 'g', 'd', 'f')
# ('j', 'g', 'd', 'h')
# ('j', 'g', 'd', 'i')
# ('j', 'g', 'e', 'a')
# ('j', 'g', 'e', 'b')
# ('j', 'g', 'e', 'c')
# ('j', 'g', 'e', 'd')
# ('j', 'g', 'e', 'f')
# ('j', 'g', 'e', 'h')
# ('j', 'g', 'e', 'i')
# ('j', 'g', 'f', 'a')
# ('j', 'g', 'f', 'b')
# ('j', 'g', 'f', 'c')
# ('j', 'g', 'f', 'd')
# ('j', 'g', 'f', 'e')
# ('j', 'g', 'f', 'h')
# ('j', 'g', 'f', 'i')
# ('j', 'g', 'h', 'a')
# ('j', 'g', 'h', 'b')
# ('j', 'g', 'h', 'c')
# ('j', 'g', 'h', 'd')
# ('j', 'g', 'h', 'e')
# ('j', 'g', 'h', 'f')
# ('j', 'g', 'h', 'i')
# ('j', 'g', 'i', 'a')
# ('j', 'g', 'i', 'b')
# ('j', 'g', 'i', 'c')
# ('j', 'g', 'i', 'd')
# ('j', 'g', 'i', 'e')
# ('j', 'g', 'i', 'f')
# ('j', 'g', 'i', 'h')
# ('j', 'h', 'a', 'b')
# ('j', 'h', 'a', 'c')
# ('j', 'h', 'a', 'd')
# ('j', 'h', 'a', 'e')
# ('j', 'h', 'a', 'f')
# ('j', 'h', 'a', 'g')
# ('j', 'h', 'a', 'i')
# ('j', 'h', 'b', 'a')
# ('j', 'h', 'b', 'c')
# ('j', 'h', 'b', 'd')
# ('j', 'h', 'b', 'e')
# ('j', 'h', 'b', 'f')
# ('j', 'h', 'b', 'g')
# ('j', 'h', 'b', 'i')
# ('j', 'h', 'c', 'a')
# ('j', 'h', 'c', 'b')
# ('j', 'h', 'c', 'd')
# ('j', 'h', 'c', 'e')
# ('j', 'h', 'c', 'f')
# ('j', 'h', 'c', 'g')
# ('j', 'h', 'c', 'i')
# ('j', 'h', 'd', 'a')
# ('j', 'h', 'd', 'b')
# ('j', 'h', 'd', 'c')
# ('j', 'h', 'd', 'e')
# ('j', 'h', 'd', 'f')
# ('j', 'h', 'd', 'g')
# ('j', 'h', 'd', 'i')
# ('j', 'h', 'e', 'a')
# ('j', 'h', 'e', 'b')
# ('j', 'h', 'e', 'c')
# ('j', 'h', 'e', 'd')
# ('j', 'h', 'e', 'f')
# ('j', 'h', 'e', 'g')
# ('j', 'h', 'e', 'i')
# ('j', 'h', 'f', 'a')
# ('j', 'h', 'f', 'b')
# ('j', 'h', 'f', 'c')
# ('j', 'h', 'f', 'd')
# ('j', 'h', 'f', 'e')
# ('j', 'h', 'f', 'g')
# ('j', 'h', 'f', 'i')
# ('j', 'h', 'g', 'a')
# ('j', 'h', 'g', 'b')
# ('j', 'h', 'g', 'c')
# ('j', 'h', 'g', 'd')
# ('j', 'h', 'g', 'e')
# ('j', 'h', 'g', 'f')
# ('j', 'h', 'g', 'i')
# ('j', 'h', 'i', 'a')
# ('j', 'h', 'i', 'b')
# ('j', 'h', 'i', 'c')
# ('j', 'h', 'i', 'd')
# ('j', 'h', 'i', 'e')
# ('j', 'h', 'i', 'f')
# ('j', 'h', 'i', 'g')
# ('j', 'i', 'a', 'b')
# ('j', 'i', 'a', 'c')
# ('j', 'i', 'a', 'd')
# ('j', 'i', 'a', 'e')
# ('j', 'i', 'a', 'f')
# ('j', 'i', 'a', 'g')
# ('j', 'i', 'a', 'h')
# ('j', 'i', 'b', 'a')
# ('j', 'i', 'b', 'c')
# ('j', 'i', 'b', 'd')
# ('j', 'i', 'b', 'e')
# ('j', 'i', 'b', 'f')
# ('j', 'i', 'b', 'g')
# ('j', 'i', 'b', 'h')
# ('j', 'i', 'c', 'a')
# ('j', 'i', 'c', 'b')
# ('j', 'i', 'c', 'd')
# ('j', 'i', 'c', 'e')
# ('j', 'i', 'c', 'f')
# ('j', 'i', 'c', 'g')
# ('j', 'i', 'c', 'h')
# ('j', 'i', 'd', 'a')
# ('j', 'i', 'd', 'b')
# ('j', 'i', 'd', 'c')
# ('j', 'i', 'd', 'e')
# ('j', 'i', 'd', 'f')
# ('j', 'i', 'd', 'g')
# ('j', 'i', 'd', 'h')
# ('j', 'i', 'e', 'a')
# ('j', 'i', 'e', 'b')
# ('j', 'i', 'e', 'c')
# ('j', 'i', 'e', 'd')
# ('j', 'i', 'e', 'f')
# ('j', 'i', 'e', 'g')
# ('j', 'i', 'e', 'h')
# ('j', 'i', 'f', 'a')
# ('j', 'i', 'f', 'b')
# ('j', 'i', 'f', 'c')
# ('j', 'i', 'f', 'd')
# ('j', 'i', 'f', 'e')
# ('j', 'i', 'f', 'g')
# ('j', 'i', 'f', 'h')
# ('j', 'i', 'g', 'a')
# ('j', 'i', 'g', 'b')
# ('j', 'i', 'g', 'c')
# ('j', 'i', 'g', 'd')
# ('j', 'i', 'g', 'e')
# ('j', 'i', 'g', 'f')
# ('j', 'i', 'g', 'h')
# ('j', 'i', 'h', 'a')
# ('j', 'i', 'h', 'b')
# ('j', 'i', 'h', 'c')
# ('j', 'i', 'h', 'd')
# ('j', 'i', 'h', 'e')
# ('j', 'i', 'h', 'f')
# ('j', 'i', 'h', 'g')
